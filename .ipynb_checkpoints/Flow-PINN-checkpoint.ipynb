# %% [markdown]
# #### **Description**

# %%
print('Name:Leo pauly')
print('Description: Program for implementing Flow-PINN')
# Out:
# Name:Leo pauly
# Description: Program for implementing Flow-PINN

# %% [markdown]
# For reference, PINN & SciANN package tutorial: https://www.youtube.com/watch?v=20NEQFcdp3o&ab_channel=DesignSafe-CIMedia

# %% [markdown]
# #### **Install**
#
# This will install SciANN library and all the dependecies

# %%
# !pip install sciann
# Out:
# Requirement already satisfied: sciann in /usr/local/lib/python3.7/dist-packages (0.6.4.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sciann) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from sciann) (1.15.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from sciann) (0.0)
# Requirement already satisfied: tensorflow>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from sciann) (2.5.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from sciann) (3.13)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.7/dist-packages (from sciann) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from sciann) (3.1.0)
# Requirement already satisfied: pybtex in /usr/local/lib/python3.7/dist-packages (from sciann) (0.24.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (2.5.0)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (1.34.1)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (2.5.0.dev2021032900)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (1.6.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (1.1.2)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (3.17.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (3.3.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (0.36.2)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (2.5.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (1.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (1.12.1)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (0.12.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (0.2.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (1.12)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (3.7.4.3)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->sciann) (0.4.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->sciann) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.1.0->sciann) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.1.0->sciann) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.1.0->sciann) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.1.0->sciann) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.1.0->sciann) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.1.0->sciann) (0.4.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.1.0->sciann) (57.2.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.1.0->sciann) (1.32.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.1.0->sciann) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.1.0->sciann) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.1.0->sciann) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.1.0->sciann) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.1.0->sciann) (4.6.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.1.0->sciann) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.1.0->sciann) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.1.0->sciann) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.1.0->sciann) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.1.0->sciann) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.1.0->sciann) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.1.0->sciann) (3.5.0)
# Requirement already satisfied: latexcodec>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from pybtex->sciann) (2.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->sciann) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->sciann) (1.0.1)

# %% [markdown]
# #### **Import**

# %%
import numpy as np
np.random.seed(64)
import matplotlib.pyplot as plt 
import sciann as sn 
import pandas as pd
from numpy import pi
from sciann.utils.math import diff, sign, sin
import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
np.set_printoptions(suppress=True)

# %% [markdown]
# Run the following only if using google Colab. It will ennable you to load data from google drive. Ignore if running on you local machine.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# #### **Flow-PINN**
#
# Details of defining functionls is available here: https://www.sciann.com/getting-started/functional-guide/
#
# Details of deifing the model can be found here: https://www.sciann.com/scimodels/#scimodel

# %% [markdown]
# ##### **Dimensions**
#
#
# ![image.png](data:image/png;base64,...)

# %%
L1=1
L2=.5
H1=1
H2=0

# %% [markdown]
# ##### **Inputs:** x,y
#
# ##### **Outputs:** v (x,y) (Darcy's velocity); K(x,y) (hydraulic conductivity); h (x,y)(pressure head)

# %%
x = sn.Variable('x',dtype='float64')
y = sn.Variable('y',dtype='float64')
v = sn.Functional('v', [x,y], 2*[20], 'relu')
K = sn.Functional('K', [x,y], 2*[20], 'relu')
h = sn.Functional('h', [x,y], 2*[20], 'relu')

# %% [markdown]
# ##### **Darcy's Equation:**
#
#
# ![image.png](data:image/png;base64,...)

# %%
d1 = sn.Data(v)
d2 = sn.Data(K)
d3 = sn.Data(h)
pde1=pow(diff(h, x),2)
pde2=pow(diff(h, y),2)
C1 = -v-(K*(pow(pde1+pde2,.5)))

# %% [markdown]
# **Boundary Conditions:**
#
# ![image.png](data:image/png;base64,...)

# %%
TOL = 0.001

B1 = (1 - sign(x - (-L1+TOL))) * (h-H1)
B2 = (1 + sign(x - (L1-TOL))) * (h-H2)

B3 = (1 - sign(y - (-L2+TOL))) * (-K*diff(h,y))
B4 = (1 + sign(y - (L2-TOL))) * (-K*diff(h,y))

# %% [markdown]
# Visualising boundary condition functions used:

# %%
psuedo_x=np.linspace(-2,2,100)

psuedo_x_multiplier_B1=(1 - np.sign(psuedo_x - (-L1+TOL))) 
plt.plot(psuedo_x,psuedo_x_multiplier_B1)
plt.title('Multiplier for B1 (h-H1)')
plt.xlabel('x values')
plt.show()

psuedo_x_multiplier_B2=(1 + np.sign(psuedo_x - (L1-TOL))) 
plt.plot(psuedo_x,psuedo_x_multiplier_B2)
plt.title('Multiplier for B2 (h-H2)')
plt.xlabel('x values')
plt.show()

# %%
psuedo_y=np.linspace(-2,2,100)

psuedo_y_multiplier_B3=(1 - np.sign(psuedo_y - (-L2+TOL)))
plt.plot(psuedo_y,psuedo_y_multiplier_B3)
plt.title('Multiplier for B3 (-K*diff(h,y))')
plt.xlabel('y values')
plt.show()

psuedo_y_multiplier_B4=(1 + np.sign(psuedo_y - (L2-TOL))) 
plt.plot(psuedo_y,psuedo_y_multiplier_B4)
plt.title('Multiplier for B4 (-K*diff(h,y))')
plt.xlabel('y values')
plt.show()

# %% [markdown]
# ######  **Model definition**

# %%
m = sn.SciModel([x,y], [d1,d2,d3,C1,B1,B2,B3,B4],loss_func='mse',plot_to_file='./Flow-PINN.png')

# %% [markdown]
# #### **Dataset**
#
# Datasets in .xlxs format are loaded using pandas python library: https://pandas.pydata.org/

# %%
v_data_df=pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/PINN/Darcy_Flux.xlsx')  
h_data_df=pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/PINN/Hydraulic_Head.xlsx')

# %%
x1_data=np.array(v_data_df['X'].values)
x2_data=np.array(v_data_df['Y'].values)

v_data=np.array(v_data_df['VINIT'].values)
print('v_data:',v_data.shape)

K_data=[]
for i in range(len(x1_data)):
  if ((x1_data[i]*x1_data[i])+(x2_data[i]*x2_data[i])<=(.25*L2)):
    K_data.append(0)
  else:
    K_data.append(.5)
K_data=np.array(K_data)
print('K_test:',K_data.shape)

h_data=np.array(h_data_df['FINIT'].values)
print('h_data:',h_data.shape)
# Out:
# v_data: (910,)
# K_test: (910,)
# h_data: (910,)

# %% [markdown]
# **Visualizing data**

# %%
fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_data, x2_data, c=v_data, cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('v (Darcys velocity)')
plt.colorbar()
plt.show()

# %%
fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_data, x2_data, c=K_data, cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('K (Hydraulic Conductivity)')
plt.colorbar()
plt.show()

# %%
fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_data, x2_data, c=h_data, cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('h (Pressure head)')
plt.colorbar()
plt.show()

# %%
train_test_ratio=.7
x1_train, x1_test,x2_train, x2_test, v_train, v_test,K_train, K_test,h_train, h_test = train_test_split(x1_data,x2_data, v_data,K_data,h_data, train_size=train_test_ratio, random_state=512)
print('test:train ratio:',train_test_ratio)
print('Training sizes(x1,x2,v,K,h):',x1_train.shape,x2_train.shape,v_train.shape,K_train.shape,h_train.shape)
print('Testing sizes(x1,x2,v,K,h):',x1_test.shape,x2_test.shape,v_test.shape,K_test.shape,h_test.shape)
C1_train=B1_train=B2_train=B3_train=B4_train = 'zeros'
C1_test=B1_test=B2_test=B3_test=B4_test = np.zeros(x1_test.shape)
# Out:
# test:train ratio: 0.7
# Training sizes(x1,x2,v,K,h): (637,) (637,) (637,) (637,) (637,)
# Testing sizes(x1,x2,v,K,h): (273,) (273,) (273,) (273,) (273,)

# %%
v_pred = v.eval(m, [x1_test,x2_test])
h_pred = h.eval(m, [x1_test,x2_test])
K_pred = K.eval(m, [x1_test,x1_test])
print('MSE for v before training:',(mean_squared_error(v_test,v_pred)))
print('MSE for h before training:',(mean_squared_error(h_test,h_pred)))
print('MSE for K before training:',(mean_squared_error(K_test,K_pred)))
# Out:
# MSE for v before training: 0.22000641925767042
# MSE for h before training: 0.1468149806090242
# MSE for K before training: 0.30302681696943135

# %% [markdown]
# #### **Training**
#
# Details of the model.train function can be found here: https://www.sciann.com/scimodels/#train

# %%
learning_rate=0.001
epochs=50
history = m.train([x1_train,x2_train], [v_train,K_train,h_train,C1_train,B1_train,B2_train,B3_train,B4_train], learning_rate=learning_rate, epochs=epochs, verbose=2,batch_size=100,validation_data=([x1_test,x2_test],[v_test,K_test,h_test,C1_test,B1_test,B2_test,B3_test,B4_test]))
# Out:
# Total samples: 637
# Batch size: 100
# Total batches: 7
#
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 7/7 - 13s - loss: 0.6023 - v_loss: 0.1916 - K_loss: 0.1958 - h_loss: 0.1278 - sub_8_loss: 0.0879 - mul_13_loss: 0.0099 - mul_14_loss: 3.0645e-04 - mul_17_loss: 4.3471e-05 - mul_20_loss: 4.4378e-04 - val_loss: 0.4878 - val_v_loss: 0.1442 - val_K_loss: 0.1611 - val_h_loss: 0.1042 - val_sub_8_loss: 0.0684 - val_mul_13_loss: 0.0079 - val_mul_14_loss: 3.0753e-04 - val_mul_17_loss: 3.0339e-05 - val_mul_20_loss: 0.0017 - lr: 0.0010 - time: 12.5350
# Epoch 2/50
# 7/7 - 8s - loss: 0.4286 - v_loss: 0.1239 - K_loss: 0.1514 - h_loss: 0.0928 - sub_8_loss: 0.0587 - mul_13_loss: 0.0025 - mul_14_loss: 0.0010 - mul_17_loss: 2.4350e-05 - mul_20_loss: 6.4714e-04 - val_loss: 0.3581 - val_v_loss: 0.0928 - val_K_loss: 0.1294 - val_h_loss: 0.0754 - val_sub_8_loss: 0.0549 - val_mul_13_loss: 0.0037 - val_mul_14_loss: 7.0719e-04 - val_mul_17_loss: 8.6936e-05 - val_mul_20_loss: 0.0011 - lr: 0.0010 - time: 8.1129
# Epoch 3/50
# 7/7 - 9s - loss: 0.3264 - v_loss: 0.0808 - K_loss: 0.1179 - h_loss: 0.0668 - sub_8_loss: 0.0530 - mul_13_loss: 0.0021 - mul_14_loss: 0.0019 - mul_17_loss: 1.7583e-04 - mul_20_loss: 6.2142e-04 - val_loss: 0.2925 - val_v_loss: 0.0663 - val_K_loss: 0.1074 - val_h_loss: 0.0549 - val_sub_8_loss: 0.0607 - val_mul_13_loss: 0.0012 - val_mul_14_loss: 7.9479e-04 - val_mul_17_loss: 3.6084e-04 - val_mul_20_loss: 7.5896e-04 - lr: 0.0010 - time: 8.5011
# Epoch 4/50
# 7/7 - 9s - loss: 0.2731 - v_loss: 0.0619 - K_loss: 0.0990 - h_loss: 0.0504 - sub_8_loss: 0.0608 - mul_13_loss: 0.0017 - mul_14_loss: 0.0016 - mul_17_loss: 5.2901e-04 - mul_20_loss: 6.7965e-04 - val_loss: 0.2636 - val_v_loss: 0.0586 - val_K_loss: 0.0937 - val_h_loss: 0.0423 - val_sub_8_loss: 0.0661 - val_mul_13_loss: 6.0700e-04 - val_mul_14_loss: 6.1860e-04 - val_mul_17_loss: 8.4490e-04 - val_mul_20_loss: 7.8507e-04 - lr: 0.0010 - time: 8.6181
# Epoch 5/50
# 7/7 - 9s - loss: 0.2514 - v_loss: 0.0568 - K_loss: 0.0824 - h_loss: 0.0395 - sub_8_loss: 0.0645 - mul_13_loss: 0.0020 - mul_14_loss: 0.0014 - mul_17_loss: 9.7517e-04 - mul_20_loss: 6.0173e-04 - val_loss: 0.2499 - val_v_loss: 0.0613 - val_K_loss: 0.0806 - val_h_loss: 0.0357 - val_sub_8_loss: 0.0686 - val_mul_13_loss: 0.0011 - val_mul_14_loss: 3.2413e-04 - val_mul_17_loss: 0.0012 - val_mul_20_loss: 9.8378e-04 - lr: 0.0010 - time: 9.3084
# Epoch 6/50
# 7/7 - 9s - loss: 0.2377 - v_loss: 0.0639 - K_loss: 0.0706 - h_loss: 0.0347 - sub_8_loss: 0.0646 - mul_13_loss: 0.0024 - mul_14_loss: 6.7101e-04 - mul_17_loss: 0.0015 - mul_20_loss: 7.5589e-04 - val_loss: 0.2399 - val_v_loss: 0.0690 - val_K_loss: 0.0697 - val_h_loss: 0.0319 - val_sub_8_loss: 0.0654 - val_mul_13_loss: 0.0013 - val_mul_14_loss: 1.7823e-04 - val_mul_17_loss: 0.0014 - val_mul_20_loss: 0.0011 - lr: 0.0010 - time: 8.7579
# Epoch 7/50
# 7/7 - 9s - loss: 0.2281 - v_loss: 0.0686 - K_loss: 0.0612 - h_loss: 0.0318 - sub_8_loss: 0.0597 - mul_13_loss: 0.0026 - mul_14_loss: 4.4731e-04 - mul_17_loss: 0.0013 - mul_20_loss: 9.8958e-04 - val_loss: 0.2314 - val_v_loss: 0.0769 - val_K_loss: 0.0630 - val_h_loss: 0.0296 - val_sub_8_loss: 0.0588 - val_mul_13_loss: 7.5497e-04 - val_mul_14_loss: 1.4789e-04 - val_mul_17_loss: 0.0013 - val_mul_20_loss: 0.0010 - lr: 0.0010 - time: 8.8579
# Epoch 8/50
# 7/7 - 9s - loss: 0.2202 - v_loss: 0.0762 - K_loss: 0.0557 - h_loss: 0.0297 - sub_8_loss: 0.0547 - mul_13_loss: 9.3279e-04 - mul_14_loss: 5.6193e-04 - mul_17_loss: 0.0013 - mul_20_loss: 0.0011 - val_loss: 0.2241 - val_v_loss: 0.0812 - val_K_loss: 0.0564 - val_h_loss: 0.0275 - val_sub_8_loss: 0.0556 - val_mul_13_loss: 3.6272e-04 - val_mul_14_loss: 2.5028e-04 - val_mul_17_loss: 0.0014 - val_mul_20_loss: 0.0014 - lr: 0.0010 - time: 9.1139
# Epoch 9/50
# 7/7 - 9s - loss: 0.2146 - v_loss: 0.0778 - K_loss: 0.0502 - h_loss: 0.0277 - sub_8_loss: 0.0531 - mul_13_loss: 4.3024e-04 - mul_14_loss: 7.5089e-04 - mul_17_loss: 0.0014 - mul_20_loss: 0.0012 - val_loss: 0.2184 - val_v_loss: 0.0814 - val_K_loss: 0.0537 - val_h_loss: 0.0265 - val_sub_8_loss: 0.0535 - val_mul_13_loss: 1.4393e-04 - val_mul_14_loss: 3.3070e-04 - val_mul_17_loss: 0.0014 - val_mul_20_loss: 0.0014 - lr: 0.0010 - time: 9.3875
# Epoch 10/50
# 7/7 - 10s - loss: 0.2105 - v_loss: 0.0786 - K_loss: 0.0493 - h_loss: 0.0272 - sub_8_loss: 0.0529 - mul_13_loss: 1.7752e-04 - mul_14_loss: 0.0011 - mul_17_loss: 0.0016 - mul_20_loss: 7.8589e-04 - val_loss: 0.2137 - val_v_loss: 0.0792 - val_K_loss: 0.0513 - val_h_loss: 0.0252 - val_sub_8_loss: 0.0550 - val_mul_13_loss: 1.1927e-04 - val_mul_14_loss: 3.4600e-04 - val_mul_17_loss: 0.0012 - val_mul_20_loss: 0.0012 - lr: 0.0010 - time: 9.8593
# Epoch 11/50
# 7/7 - 10s - loss: 0.2062 - v_loss: 0.0755 - K_loss: 0.0479 - h_loss: 0.0252 - sub_8_loss: 0.0538 - mul_13_loss: 1.2340e-04 - mul_14_loss: 0.0010 - mul_17_loss: 0.0013 - mul_20_loss: 0.0011 - val_loss: 0.2090 - val_v_loss: 0.0767 - val_K_loss: 0.0505 - val_h_loss: 0.0241 - val_sub_8_loss: 0.0549 - val_mul_13_loss: 1.2844e-04 - val_mul_14_loss: 3.5925e-04 - val_mul_17_loss: 0.0013 - val_mul_20_loss: 9.7789e-04 - lr: 0.0010 - time: 9.9016
# Epoch 12/50
# 7/7 - 10s - loss: 0.2033 - v_loss: 0.0740 - K_loss: 0.0493 - h_loss: 0.0250 - sub_8_loss: 0.0531 - mul_13_loss: 6.8354e-05 - mul_14_loss: 0.0015 - mul_17_loss: 0.0012 - mul_20_loss: 7.8134e-04 - val_loss: 0.2049 - val_v_loss: 0.0736 - val_K_loss: 0.0508 - val_h_loss: 0.0233 - val_sub_8_loss: 0.0549 - val_mul_13_loss: 1.5013e-04 - val_mul_14_loss: 4.6173e-04 - val_mul_17_loss: 0.0011 - val_mul_20_loss: 7.5591e-04 - lr: 0.0010 - time: 10.0869
# Epoch 13/50
# 7/7 - 10s - loss: 0.2000 - v_loss: 0.0712 - K_loss: 0.0451 - h_loss: 0.0220 - sub_8_loss: 0.0574 - mul_13_loss: 6.2848e-05 - mul_14_loss: 0.0012 - mul_17_loss: 0.0011 - mul_20_loss: 6.3940e-04 - val_loss: 0.2025 - val_v_loss: 0.0739 - val_K_loss: 0.0449 - val_h_loss: 0.0224 - val_sub_8_loss: 0.0591 - val_mul_13_loss: 1.4473e-04 - val_mul_14_loss: 3.3985e-04 - val_mul_17_loss: 0.0012 - val_mul_20_loss: 5.8670e-04 - lr: 0.0010 - time: 10.2370
# Epoch 14/50
# 7/7 - 11s - loss: 0.1965 - v_loss: 0.0717 - K_loss: 0.0444 - h_loss: 0.0222 - sub_8_loss: 0.0546 - mul_13_loss: 3.5673e-05 - mul_14_loss: 0.0012 - mul_17_loss: 0.0011 - mul_20_loss: 4.9831e-04 - val_loss: 0.2004 - val_v_loss: 0.0750 - val_K_loss: 0.0468 - val_h_loss: 0.0229 - val_sub_8_loss: 0.0534 - val_mul_13_loss: 8.2278e-05 - val_mul_14_loss: 5.3164e-04 - val_mul_17_loss: 0.0013 - val_mul_20_loss: 4.7959e-04 - lr: 0.0010 - time: 10.7743
# Epoch 15/50
# 7/7 - 11s - loss: 0.1949 - v_loss: 0.0729 - K_loss: 0.0442 - h_loss: 0.0221 - sub_8_loss: 0.0525 - mul_13_loss: 1.2240e-05 - mul_14_loss: 0.0017 - mul_17_loss: 0.0014 - mul_20_loss: 3.6116e-04 - val_loss: 0.1991 - val_v_loss: 0.0747 - val_K_loss: 0.0420 - val_h_loss: 0.0233 - val_sub_8_loss: 0.0563 - val_mul_13_loss: 5.1137e-05 - val_mul_14_loss: 6.6349e-04 - val_mul_17_loss: 0.0014 - val_mul_20_loss: 6.3793e-04 - lr: 0.0010 - time: 10.6953
# Epoch 16/50
# 7/7 - 11s - loss: 0.1942 - v_loss: 0.0725 - K_loss: 0.0398 - h_loss: 0.0227 - sub_8_loss: 0.0566 - mul_13_loss: 1.0431e-05 - mul_14_loss: 0.0019 - mul_17_loss: 0.0017 - mul_20_loss: 4.2349e-04 - val_loss: 0.1974 - val_v_loss: 0.0746 - val_K_loss: 0.0402 - val_h_loss: 0.0234 - val_sub_8_loss: 0.0568 - val_mul_13_loss: 1.6292e-05 - val_mul_14_loss: 5.4796e-04 - val_mul_17_loss: 0.0013 - val_mul_20_loss: 6.2528e-04 - lr: 0.0010 - time: 11.3631
# Epoch 17/50
# 7/7 - 11s - loss: 0.1925 - v_loss: 0.0736 - K_loss: 0.0400 - h_loss: 0.0227 - sub_8_loss: 0.0543 - mul_13_loss: 2.2168e-05 - mul_14_loss: 0.0013 - mul_17_loss: 0.0011 - mul_20_loss: 3.3816e-04 - val_loss: 0.1954 - val_v_loss: 0.0753 - val_K_loss: 0.0413 - val_h_loss: 0.0233 - val_sub_8_loss: 0.0533 - val_mul_13_loss: 2.1380e-05 - val_mul_14_loss: 4.8763e-04 - val_mul_17_loss: 0.0011 - val_mul_20_loss: 5.7240e-04 - lr: 0.0010 - time: 11.1381
# Epoch 18/50
# 7/7 - 11s - loss: 0.1902 - v_loss: 0.0736 - K_loss: 0.0401 - h_loss: 0.0221 - sub_8_loss: 0.0522 - mul_13_loss: 2.9734e-05 - mul_14_loss: 0.0016 - mul_17_loss: 0.0011 - mul_20_loss: 3.0550e-04 - val_loss: 0.1932 - val_v_loss: 0.0739 - val_K_loss: 0.0389 - val_h_loss: 0.0228 - val_sub_8_loss: 0.0555 - val_mul_13_loss: 2.1902e-05 - val_mul_14_loss: 4.9665e-04 - val_mul_17_loss: 0.0011 - val_mul_20_loss: 5.2580e-04 - lr: 0.0010 - time: 11.3624
# Epoch 19/50
# 7/7 - 12s - loss: 0.1877 - v_loss: 0.0710 - K_loss: 0.0374 - h_loss: 0.0215 - sub_8_loss: 0.0546 - mul_13_loss: 2.7703e-05 - mul_14_loss: 0.0012 - mul_17_loss: 0.0011 - mul_20_loss: 3.0682e-04 - val_loss: 0.1910 - val_v_loss: 0.0725 - val_K_loss: 0.0374 - val_h_loss: 0.0221 - val_sub_8_loss: 0.0570 - val_mul_13_loss: 2.3103e-05 - val_mul_14_loss: 4.6962e-04 - val_mul_17_loss: 0.0011 - val_mul_20_loss: 5.1492e-04 - lr: 0.0010 - time: 11.9265
# Epoch 20/50
# 7/7 - 12s - loss: 0.1852 - v_loss: 0.0699 - K_loss: 0.0362 - h_loss: 0.0214 - sub_8_loss: 0.0535 - mul_13_loss: 5.0477e-05 - mul_14_loss: 0.0018 - mul_17_loss: 9.8180e-04 - mul_20_loss: 2.5146e-04 - val_loss: 0.1888 - val_v_loss: 0.0729 - val_K_loss: 0.0374 - val_h_loss: 0.0224 - val_sub_8_loss: 0.0541 - val_mul_13_loss: 7.3525e-05 - val_mul_14_loss: 5.1277e-04 - val_mul_17_loss: 9.5617e-04 - val_mul_20_loss: 4.0037e-04 - lr: 0.0010 - time: 11.7006
# Epoch 21/50
# 7/7 - 12s - loss: 0.1832 - v_loss: 0.0691 - K_loss: 0.0356 - h_loss: 0.0214 - sub_8_loss: 0.0530 - mul_13_loss: 7.4333e-05 - mul_14_loss: 0.0015 - mul_17_loss: 7.4176e-04 - mul_20_loss: 2.5522e-04 - val_loss: 0.1868 - val_v_loss: 0.0723 - val_K_loss: 0.0340 - val_h_loss: 0.0225 - val_sub_8_loss: 0.0560 - val_mul_13_loss: 8.8308e-05 - val_mul_14_loss: 6.4796e-04 - val_mul_17_loss: 8.5637e-04 - val_mul_20_loss: 4.2557e-04 - lr: 0.0010 - time: 12.4796
# Epoch 22/50
# 7/7 - 12s - loss: 0.1814 - v_loss: 0.0686 - K_loss: 0.0330 - h_loss: 0.0220 - sub_8_loss: 0.0530 - mul_13_loss: 1.0429e-04 - mul_14_loss: 0.0024 - mul_17_loss: 7.1798e-04 - mul_20_loss: 1.7955e-04 - val_loss: 0.1855 - val_v_loss: 0.0720 - val_K_loss: 0.0349 - val_h_loss: 0.0227 - val_sub_8_loss: 0.0542 - val_mul_13_loss: 1.9090e-04 - val_mul_14_loss: 5.1992e-04 - val_mul_17_loss: 6.4633e-04 - val_mul_20_loss: 3.5229e-04 - lr: 0.0010 - time: 12.2845
# Epoch 23/50
# 7/7 - 13s - loss: 0.1797 - v_loss: 0.0685 - K_loss: 0.0350 - h_loss: 0.0223 - sub_8_loss: 0.0522 - mul_13_loss: 1.8713e-04 - mul_14_loss: 0.0015 - mul_17_loss: 8.0662e-04 - mul_20_loss: 1.4836e-04 - val_loss: 0.1844 - val_v_loss: 0.0705 - val_K_loss: 0.0343 - val_h_loss: 0.0222 - val_sub_8_loss: 0.0558 - val_mul_13_loss: 2.0695e-04 - val_mul_14_loss: 4.1274e-04 - val_mul_17_loss: 5.9928e-04 - val_mul_20_loss: 3.5818e-04 - lr: 0.0010 - time: 12.6838
# Epoch 24/50
# 7/7 - 12s - loss: 0.1779 - v_loss: 0.0680 - K_loss: 0.0341 - h_loss: 0.0201 - sub_8_loss: 0.0545 - mul_13_loss: 1.4444e-04 - mul_14_loss: 0.0013 - mul_17_loss: 8.4064e-04 - mul_20_loss: 1.6911e-04 - val_loss: 0.1819 - val_v_loss: 0.0696 - val_K_loss: 0.0335 - val_h_loss: 0.0219 - val_sub_8_loss: 0.0551 - val_mul_13_loss: 1.6862e-04 - val_mul_14_loss: 6.1728e-04 - val_mul_17_loss: 5.9108e-04 - val_mul_20_loss: 3.9694e-04 - lr: 0.0010 - time: 12.3800
# Epoch 25/50
# 7/7 - 13s - loss: 0.1764 - v_loss: 0.0672 - K_loss: 0.0333 - h_loss: 0.0210 - sub_8_loss: 0.0536 - mul_13_loss: 1.3099e-04 - mul_14_loss: 0.0016 - mul_17_loss: 8.0055e-04 - mul_20_loss: 1.7668e-04 - val_loss: 0.1805 - val_v_loss: 0.0695 - val_K_loss: 0.0324 - val_h_loss: 0.0220 - val_sub_8_loss: 0.0549 - val_mul_13_loss: 2.3683e-04 - val_mul_14_loss: 6.1877e-04 - val_mul_17_loss: 4.8057e-04 - val_mul_20_loss: 4.1599e-04 - lr: 0.0010 - time: 12.9788
# Epoch 26/50
# 7/7 - 13s - loss: 0.1751 - v_loss: 0.0657 - K_loss: 0.0321 - h_loss: 0.0217 - sub_8_loss: 0.0512 - mul_13_loss: 2.5693e-04 - mul_14_loss: 0.0017 - mul_17_loss: 5.7890e-04 - mul_20_loss: 1.9172e-04 - val_loss: 0.1783 - val_v_loss: 0.0678 - val_K_loss: 0.0336 - val_h_loss: 0.0221 - val_sub_8_loss: 0.0531 - val_mul_13_loss: 3.4664e-04 - val_mul_14_loss: 5.9779e-04 - val_mul_17_loss: 4.1659e-04 - val_mul_20_loss: 3.7697e-04 - lr: 0.0010 - time: 12.6054
# Epoch 27/50
# 7/7 - 13s - loss: 0.1739 - v_loss: 0.0660 - K_loss: 0.0321 - h_loss: 0.0218 - sub_8_loss: 0.0528 - mul_13_loss: 3.3016e-04 - mul_14_loss: 0.0016 - mul_17_loss: 6.0904e-04 - mul_20_loss: 2.6884e-04 - val_loss: 0.1789 - val_v_loss: 0.0683 - val_K_loss: 0.0302 - val_h_loss: 0.0222 - val_sub_8_loss: 0.0561 - val_mul_13_loss: 4.1925e-04 - val_mul_14_loss: 6.0701e-04 - val_mul_17_loss: 5.3003e-04 - val_mul_20_loss: 5.1829e-04 - lr: 0.0010 - time: 13.2028
# Epoch 28/50
# 7/7 - 13s - loss: 0.1728 - v_loss: 0.0637 - K_loss: 0.0291 - h_loss: 0.0208 - sub_8_loss: 0.0519 - mul_13_loss: 3.1918e-04 - mul_14_loss: 0.0025 - mul_17_loss: 5.8220e-04 - mul_20_loss: 2.5563e-04 - val_loss: 0.1784 - val_v_loss: 0.0682 - val_K_loss: 0.0325 - val_h_loss: 0.0219 - val_sub_8_loss: 0.0539 - val_mul_13_loss: 4.7014e-04 - val_mul_14_loss: 4.2945e-04 - val_mul_17_loss: 4.4601e-04 - val_mul_20_loss: 4.7523e-04 - lr: 0.0010 - time: 13.3858
# Epoch 29/50
# 7/7 - 14s - loss: 0.1719 - v_loss: 0.0632 - K_loss: 0.0323 - h_loss: 0.0212 - sub_8_loss: 0.0512 - mul_13_loss: 3.4937e-04 - mul_14_loss: 0.0014 - mul_17_loss: 7.0232e-04 - mul_20_loss: 2.1737e-04 - val_loss: 0.1783 - val_v_loss: 0.0672 - val_K_loss: 0.0329 - val_h_loss: 0.0216 - val_sub_8_loss: 0.0547 - val_mul_13_loss: 4.7253e-04 - val_mul_14_loss: 3.8860e-04 - val_mul_17_loss: 5.4204e-04 - val_mul_20_loss: 5.2489e-04 - lr: 0.0010 - time: 13.7280
# Epoch 30/50
# 7/7 - 13s - loss: 0.1703 - v_loss: 0.0628 - K_loss: 0.0310 - h_loss: 0.0212 - sub_8_loss: 0.0517 - mul_13_loss: 3.4885e-04 - mul_14_loss: 0.0016 - mul_17_loss: 4.2792e-04 - mul_20_loss: 3.3870e-04 - val_loss: 0.1761 - val_v_loss: 0.0667 - val_K_loss: 0.0307 - val_h_loss: 0.0217 - val_sub_8_loss: 0.0549 - val_mul_13_loss: 4.9411e-04 - val_mul_14_loss: 5.8508e-04 - val_mul_17_loss: 4.1740e-04 - val_mul_20_loss: 5.7228e-04 - lr: 0.0010 - time: 13.4510
# Epoch 31/50
# 7/7 - 14s - loss: 0.1691 - v_loss: 0.0633 - K_loss: 0.0295 - h_loss: 0.0209 - sub_8_loss: 0.0529 - mul_13_loss: 4.6359e-04 - mul_14_loss: 0.0016 - mul_17_loss: 4.5925e-04 - mul_20_loss: 3.5351e-04 - val_loss: 0.1744 - val_v_loss: 0.0657 - val_K_loss: 0.0291 - val_h_loss: 0.0221 - val_sub_8_loss: 0.0553 - val_mul_13_loss: 6.8686e-04 - val_mul_14_loss: 6.1690e-04 - val_mul_17_loss: 3.9488e-04 - val_mul_20_loss: 6.0207e-04 - lr: 0.0010 - time: 13.9889
# Epoch 32/50
# 7/7 - 15s - loss: 0.1682 - v_loss: 0.0638 - K_loss: 0.0302 - h_loss: 0.0200 - sub_8_loss: 0.0520 - mul_13_loss: 5.9001e-04 - mul_14_loss: 0.0018 - mul_17_loss: 4.9016e-04 - mul_20_loss: 3.9714e-04 - val_loss: 0.1741 - val_v_loss: 0.0653 - val_K_loss: 0.0315 - val_h_loss: 0.0217 - val_sub_8_loss: 0.0533 - val_mul_13_loss: 7.6649e-04 - val_mul_14_loss: 4.6501e-04 - val_mul_17_loss: 4.3768e-04 - val_mul_20_loss: 6.7387e-04 - lr: 0.0010 - time: 14.5443
# Epoch 33/50
# 7/7 - 14s - loss: 0.1677 - v_loss: 0.0615 - K_loss: 0.0292 - h_loss: 0.0200 - sub_8_loss: 0.0519 - mul_13_loss: 6.4216e-04 - mul_14_loss: 0.0018 - mul_17_loss: 4.2988e-04 - mul_20_loss: 3.5779e-04 - val_loss: 0.1754 - val_v_loss: 0.0650 - val_K_loss: 0.0286 - val_h_loss: 0.0216 - val_sub_8_loss: 0.0572 - val_mul_13_loss: 7.8672e-04 - val_mul_14_loss: 4.7591e-04 - val_mul_17_loss: 8.7449e-04 - val_mul_20_loss: 8.2425e-04 - lr: 0.0010 - time: 14.2447
# Epoch 34/50
# 7/7 - 15s - loss: 0.1668 - v_loss: 0.0620 - K_loss: 0.0288 - h_loss: 0.0201 - sub_8_loss: 0.0519 - mul_13_loss: 6.7249e-04 - mul_14_loss: 0.0013 - mul_17_loss: 4.3158e-04 - mul_20_loss: 4.1428e-04 - val_loss: 0.1741 - val_v_loss: 0.0652 - val_K_loss: 0.0298 - val_h_loss: 0.0219 - val_sub_8_loss: 0.0541 - val_mul_13_loss: 8.2108e-04 - val_mul_14_loss: 5.7998e-04 - val_mul_17_loss: 8.7248e-04 - val_mul_20_loss: 9.0670e-04 - lr: 0.0010 - time: 14.9611
# Epoch 35/50
# 7/7 - 15s - loss: 0.1657 - v_loss: 0.0616 - K_loss: 0.0292 - h_loss: 0.0204 - sub_8_loss: 0.0516 - mul_13_loss: 7.0007e-04 - mul_14_loss: 0.0017 - mul_17_loss: 3.3340e-04 - mul_20_loss: 4.3854e-04 - val_loss: 0.1715 - val_v_loss: 0.0628 - val_K_loss: 0.0303 - val_h_loss: 0.0212 - val_sub_8_loss: 0.0542 - val_mul_13_loss: 7.0406e-04 - val_mul_14_loss: 5.7487e-04 - val_mul_17_loss: 7.7506e-04 - val_mul_20_loss: 9.3994e-04 - lr: 0.0010 - time: 15.2480
# Epoch 36/50
# 7/7 - 15s - loss: 0.1651 - v_loss: 0.0616 - K_loss: 0.0294 - h_loss: 0.0203 - sub_8_loss: 0.0529 - mul_13_loss: 8.4641e-04 - mul_14_loss: 0.0014 - mul_17_loss: 4.7165e-04 - mul_20_loss: 3.4525e-04 - val_loss: 0.1715 - val_v_loss: 0.0636 - val_K_loss: 0.0300 - val_h_loss: 0.0212 - val_sub_8_loss: 0.0537 - val_mul_13_loss: 7.9637e-04 - val_mul_14_loss: 5.2685e-04 - val_mul_17_loss: 7.6613e-04 - val_mul_20_loss: 9.0502e-04 - lr: 0.0010 - time: 14.5396
# Epoch 37/50
# 7/7 - 15s - loss: 0.1642 - v_loss: 0.0616 - K_loss: 0.0290 - h_loss: 0.0207 - sub_8_loss: 0.0512 - mul_13_loss: 7.8637e-04 - mul_14_loss: 0.0014 - mul_17_loss: 3.5709e-04 - mul_20_loss: 3.6030e-04 - val_loss: 0.1722 - val_v_loss: 0.0650 - val_K_loss: 0.0279 - val_h_loss: 0.0214 - val_sub_8_loss: 0.0550 - val_mul_13_loss: 8.2538e-04 - val_mul_14_loss: 5.2131e-04 - val_mul_17_loss: 8.9388e-04 - val_mul_20_loss: 6.1531e-04 - lr: 0.0010 - time: 15.4838
# Epoch 38/50
# 7/7 - 16s - loss: 0.1637 - v_loss: 0.0622 - K_loss: 0.0270 - h_loss: 0.0196 - sub_8_loss: 0.0530 - mul_13_loss: 7.5986e-04 - mul_14_loss: 0.0013 - mul_17_loss: 4.7697e-04 - mul_20_loss: 3.3621e-04 - val_loss: 0.1725 - val_v_loss: 0.0633 - val_K_loss: 0.0280 - val_h_loss: 0.0220 - val_sub_8_loss: 0.0563 - val_mul_13_loss: 0.0010 - val_mul_14_loss: 5.1518e-04 - val_mul_17_loss: 8.2156e-04 - val_mul_20_loss: 6.3025e-04 - lr: 0.0010 - time: 15.6608
# Epoch 39/50
# 7/7 - 15s - loss: 0.1635 - v_loss: 0.0607 - K_loss: 0.0287 - h_loss: 0.0198 - sub_8_loss: 0.0535 - mul_13_loss: 8.1190e-04 - mul_14_loss: 0.0020 - mul_17_loss: 4.0508e-04 - mul_20_loss: 2.9935e-04 - val_loss: 0.1719 - val_v_loss: 0.0626 - val_K_loss: 0.0277 - val_h_loss: 0.0222 - val_sub_8_loss: 0.0562 - val_mul_13_loss: 0.0010 - val_mul_14_loss: 5.8030e-04 - val_mul_17_loss: 9.6999e-04 - val_mul_20_loss: 6.2668e-04 - lr: 0.0010 - time: 15.1644
# Epoch 40/50
# 7/7 - 16s - loss: 0.1630 - v_loss: 0.0597 - K_loss: 0.0263 - h_loss: 0.0204 - sub_8_loss: 0.0512 - mul_13_loss: 8.4644e-04 - mul_14_loss: 0.0016 - mul_17_loss: 3.4739e-04 - mul_20_loss: 3.1771e-04 - val_loss: 0.1721 - val_v_loss: 0.0641 - val_K_loss: 0.0279 - val_h_loss: 0.0222 - val_sub_8_loss: 0.0548 - val_mul_13_loss: 0.0011 - val_mul_14_loss: 4.8706e-04 - val_mul_17_loss: 9.2795e-04 - val_mul_20_loss: 6.0132e-04 - lr: 0.0010 - time: 15.6212
# Epoch 41/50
# 7/7 - 16s - loss: 0.1626 - v_loss: 0.0612 - K_loss: 0.0268 - h_loss: 0.0196 - sub_8_loss: 0.0515 - mul_13_loss: 9.7444e-04 - mul_14_loss: 0.0014 - mul_17_loss: 4.2294e-04 - mul_20_loss: 2.1564e-04 - val_loss: 0.1718 - val_v_loss: 0.0625 - val_K_loss: 0.0278 - val_h_loss: 0.0217 - val_sub_8_loss: 0.0571 - val_mul_13_loss: 9.2188e-04 - val_mul_14_loss: 4.8269e-04 - val_mul_17_loss: 8.8367e-04 - val_mul_20_loss: 5.1977e-04 - lr: 0.0010 - time: 16.0262
# Epoch 42/50
# 7/7 - 16s - loss: 0.1619 - v_loss: 0.0597 - K_loss: 0.0256 - h_loss: 0.0192 - sub_8_loss: 0.0526 - mul_13_loss: 7.0758e-04 - mul_14_loss: 0.0014 - mul_17_loss: 4.4528e-04 - mul_20_loss: 2.2813e-04 - val_loss: 0.1730 - val_v_loss: 0.0621 - val_K_loss: 0.0275 - val_h_loss: 0.0222 - val_sub_8_loss: 0.0582 - val_mul_13_loss: 8.9420e-04 - val_mul_14_loss: 5.9984e-04 - val_mul_17_loss: 8.9031e-04 - val_mul_20_loss: 6.7559e-04 - lr: 0.0010 - time: 16.1696
# Epoch 43/50
# 7/7 - 16s - loss: 0.1618 - v_loss: 0.0600 - K_loss: 0.0257 - h_loss: 0.0222 - sub_8_loss: 0.0505 - mul_13_loss: 6.7193e-04 - mul_14_loss: 0.0018 - mul_17_loss: 2.1913e-04 - mul_20_loss: 2.7348e-04 - val_loss: 0.1713 - val_v_loss: 0.0624 - val_K_loss: 0.0278 - val_h_loss: 0.0223 - val_sub_8_loss: 0.0560 - val_mul_13_loss: 9.9120e-04 - val_mul_14_loss: 4.8912e-04 - val_mul_17_loss: 7.6675e-04 - val_mul_20_loss: 6.0880e-04 - lr: 0.0010 - time: 15.8072
# Epoch 44/50
# 7/7 - 17s - loss: 0.1621 - v_loss: 0.0607 - K_loss: 0.0248 - h_loss: 0.0206 - sub_8_loss: 0.0525 - mul_13_loss: 9.9878e-04 - mul_14_loss: 0.0013 - mul_17_loss: 3.0253e-04 - mul_20_loss: 2.1468e-04 - val_loss: 0.1721 - val_v_loss: 0.0625 - val_K_loss: 0.0256 - val_h_loss: 0.0227 - val_sub_8_loss: 0.0586 - val_mul_13_loss: 0.0010 - val_mul_14_loss: 4.1352e-04 - val_mul_17_loss: 7.3512e-04 - val_mul_20_loss: 5.5498e-04 - lr: 0.0010 - time: 16.6078
# Epoch 45/50
# 7/7 - 17s - loss: 0.1618 - v_loss: 0.0614 - K_loss: 0.0243 - h_loss: 0.0205 - sub_8_loss: 0.0539 - mul_13_loss: 8.7387e-04 - mul_14_loss: 0.0011 - mul_17_loss: 2.5540e-04 - mul_20_loss: 2.0019e-04 - val_loss: 0.1715 - val_v_loss: 0.0638 - val_K_loss: 0.0260 - val_h_loss: 0.0227 - val_sub_8_loss: 0.0564 - val_mul_13_loss: 8.2974e-04 - val_mul_14_loss: 5.4722e-04 - val_mul_17_loss: 6.4347e-04 - val_mul_20_loss: 4.8185e-04 - lr: 0.0010 - time: 16.7057
# Epoch 46/50
# 7/7 - 17s - loss: 0.1614 - v_loss: 0.0606 - K_loss: 0.0243 - h_loss: 0.0210 - sub_8_loss: 0.0504 - mul_13_loss: 7.5021e-04 - mul_14_loss: 0.0021 - mul_17_loss: 1.9095e-04 - mul_20_loss: 1.7026e-04 - val_loss: 0.1716 - val_v_loss: 0.0622 - val_K_loss: 0.0265 - val_h_loss: 0.0225 - val_sub_8_loss: 0.0581 - val_mul_13_loss: 7.5037e-04 - val_mul_14_loss: 5.3089e-04 - val_mul_17_loss: 5.5132e-04 - val_mul_20_loss: 4.8565e-04 - lr: 0.0010 - time: 16.8107
# Epoch 47/50
# 7/7 - 16s - loss: 0.1614 - v_loss: 0.0597 - K_loss: 0.0248 - h_loss: 0.0209 - sub_8_loss: 0.0535 - mul_13_loss: 9.1405e-04 - mul_14_loss: 0.0016 - mul_17_loss: 1.5548e-04 - mul_20_loss: 1.6849e-04 - val_loss: 0.1709 - val_v_loss: 0.0637 - val_K_loss: 0.0245 - val_h_loss: 0.0228 - val_sub_8_loss: 0.0576 - val_mul_13_loss: 8.9750e-04 - val_mul_14_loss: 4.4735e-04 - val_mul_17_loss: 5.0901e-04 - val_mul_20_loss: 3.6139e-04 - lr: 0.0010 - time: 16.4621
# Epoch 48/50
# 7/7 - 17s - loss: 0.1613 - v_loss: 0.0631 - K_loss: 0.0239 - h_loss: 0.0225 - sub_8_loss: 0.0518 - mul_13_loss: 0.0010 - mul_14_loss: 0.0014 - mul_17_loss: 1.6496e-04 - mul_20_loss: 2.0354e-04 - val_loss: 0.1697 - val_v_loss: 0.0644 - val_K_loss: 0.0247 - val_h_loss: 0.0233 - val_sub_8_loss: 0.0551 - val_mul_13_loss: 8.4104e-04 - val_mul_14_loss: 6.5048e-04 - val_mul_17_loss: 4.3199e-04 - val_mul_20_loss: 2.9128e-04 - lr: 0.0010 - time: 17.3754
# Epoch 49/50
# 7/7 - 17s - loss: 0.1615 - v_loss: 0.0611 - K_loss: 0.0242 - h_loss: 0.0219 - sub_8_loss: 0.0514 - mul_13_loss: 9.2298e-04 - mul_14_loss: 0.0015 - mul_17_loss: 1.5547e-04 - mul_20_loss: 2.2338e-04 - val_loss: 0.1686 - val_v_loss: 0.0618 - val_K_loss: 0.0258 - val_h_loss: 0.0227 - val_sub_8_loss: 0.0564 - val_mul_13_loss: 7.5526e-04 - val_mul_14_loss: 6.0010e-04 - val_mul_17_loss: 2.9159e-04 - val_mul_20_loss: 2.9289e-04 - lr: 0.0010 - time: 17.4414
# Epoch 50/50
# 7/7 - 18s - loss: 0.1618 - v_loss: 0.0579 - K_loss: 0.0230 - h_loss: 0.0208 - sub_8_loss: 0.0542 - mul_13_loss: 8.1874e-04 - mul_14_loss: 0.0024 - mul_17_loss: 2.2537e-04 - mul_20_loss: 2.6660e-04 - val_loss: 0.1683 - val_v_loss: 0.0622 - val_K_loss: 0.0255 - val_h_loss: 0.0219 - val_sub_8_loss: 0.0570 - val_mul_13_loss: 7.1151e-04 - val_mul_14_loss: 4.8230e-04 - val_mul_17_loss: 3.4479e-04 - val_mul_20_loss: 2.7604e-04 - lr: 0.0010 - time: 17.5535

# %% [markdown]
# #### **Plotting Loss**

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'v_loss', 'K_loss', 'h_loss', 'sub_8_loss', 'mul_13_loss', 'mul_14_loss', 'mul_17_loss', 'mul_20_loss', 'val_loss', 'val_v_loss', 'val_K_loss', 'val_h_loss', 'val_sub_8_loss', 'val_mul_13_loss', 'val_mul_14_loss', 'val_mul_17_loss', 'val_mul_20_loss', 'lr', 'time'])

# %%
plt.plot(range(0,epochs),history.history['v_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_v_loss'],label='test')
plt.title('v_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['K_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_K_loss'],label='test')
plt.title('K_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['h_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_h_loss'],label='test')
plt.title('h_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['mul_13_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_mul_13_loss'],label='test')
plt.title('B1_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['mul_14_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_mul_14_loss'],label='test')
plt.title('B2_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['mul_17_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_mul_17_loss'],label='test')
plt.title('B3_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['mul_20_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_mul_20_loss'],label='test')
plt.title('B4_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['sub_8_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_sub_8_loss'],label='test')
plt.legend()
plt.title('PDE loss vs epoch')
plt.show()

# %%
plt.plot(range(0,epochs),history.history['loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_loss'],label='test')
plt.title('Net loss vs epoch')
plt.legend()
plt.show()

# %% [markdown]
# #### **Testing**

# %%
v_pred = v.eval(m, [x1_test,x2_test])
h_pred = h.eval(m, [x1_test,x2_test])
K_pred = K.eval(m, [x1_test,x2_test])
print('MSE for v after training:',round(mean_squared_error(v_test,v_pred),10))
print('MSE for h after training:',round(mean_squared_error(h_test,h_pred),10))
print('MSE for K after training:',round(mean_squared_error(K_test,K_pred),10))
# Out:
# MSE for v after training: 0.0618383013
# MSE for h after training: 0.0215442168
# MSE for K after training: 0.0260074837

# %%
fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_test, x2_test, c= v.eval(m, [x1_test,x2_test]), cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('v_pred (Darcy velocity)')
plt.colorbar()
plt.show()

fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_test, x2_test, c= v_test, cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('v_test (Darcy velocity)')
plt.colorbar()
plt.show()

# %%
fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_test, x2_test, c= K.eval(m, [x1_test,x2_test]), cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('K_pred (Hydraulic Conductivity)')
plt.colorbar()
plt.show()

fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_test, x2_test, c= K_test, cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('K_test (Hydraulic Conductivity)')
plt.colorbar()
plt.show()

# %%
fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_test, x2_test, c= h.eval(m, [x1_test,x2_test]), cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('h_pred (Pressure head)')
plt.colorbar()
plt.show()

fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_test, x2_test, c= h_test, cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('h_test (Pressure head)')
plt.colorbar()
plt.show()

# %% [markdown]
# #### **Simulating**

# %%
x1_sim, x2_sim = np.meshgrid(np.linspace(-1, 1, 100), np.linspace(-.5, .5, 100))
fig = plt.figure(figsize=(6, 3))
v_pred_sim =np.array(v.eval(m, [x1_sim,x2_sim]))
plt.contourf(x1_sim, x2_sim, v_pred_sim)
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.title('Darcys Veloctiy')
plt.show()

# %%
x1_sim, x2_sim = np.meshgrid(np.linspace(-1, 1, 100), np.linspace(-.5, .5, 100))
fig = plt.figure(figsize=(6, 3))
v_pred_sim =np.array(K.eval(m, [x1_sim,x2_sim]))
plt.contourf(x1_sim, x2_sim, v_pred_sim)
plt.xlabel('X')
plt.ylabel('Y')
plt.colorbar()
plt.title('Hydraulic Conductivty')
plt.show()

# %%
x1_sim, x2_sim = np.meshgrid(np.linspace(-1, 1, 100), np.linspace(-.5, .5, 100))
fig = plt.figure(figsize=(6, 3))
v_pred_sim =np.array(h.eval(m, [x1_sim,x2_sim]))
plt.contourf(x1_sim, x2_sim, v_pred_sim)
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.title('Pressure head')
plt.show()

# %%
print(x1_sim.shape,x2_sim.shape,v_pred_sim.shape)
