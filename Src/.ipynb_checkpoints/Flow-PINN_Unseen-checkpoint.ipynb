# %% [markdown]
# #### **Description**

# %%
print('Name:Leo pauly')
print('Description: Program for implementing Flow-PINN')
# Out:
# Name:Leo pauly
# Description: Program for implementing Flow-PINN

# %% [markdown]
# For reference, PINN & SciANN package tutorial: https://www.youtube.com/watch?v=20NEQFcdp3o&ab_channel=DesignSafe-CIMedia

# %% [markdown]
# #### **Install**
#
# This will install SciANN library and all the dependecies

# %%
#!pip install sciann

# %% [markdown]
# #### **Import**

# %%
import numpy as np
np.random.seed(64)
import matplotlib.pyplot as plt 
import sciann as sn 
import pandas as pd
from numpy import pi
from sciann.utils.math import diff, sign, sin
import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
np.set_printoptions(suppress=True)
# Out:
# ---------------------- SCIANN 0.6.3.1 ----------------------
# For details, check out our review paper and the documentation at:
#  +  "https://www.sciencedirect.com/science/article/pii/S0045782520307374",
#  +  "https://arxiv.org/abs/2005.08803",
#  +  "https://www.sciann.com".
#
#  Need support or would like to contribute, please join sciann`s slack group:
#  +  "https://join.slack.com/t/sciann/shared_invite/zt-ne1f5jlx-k_dY8RGo3ZreDXwz0f~CeA"

# %% [markdown]
# Run the following only if using google Colab. It will ennable you to load data from google drive. Ignore if running on you local machine.

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %% [markdown]
# #### **Flow-PINN**
#
# Details of defining functionls is available here: https://www.sciann.com/getting-started/functional-guide/
#
# Details of deifing the model can be found here: https://www.sciann.com/scimodels/#scimodel

# %% [markdown]
# ##### **Dimensions**
#
#
# ![image.png](data:image/png;base64,...)

# %%
L1=1
L2=.5
H1=1
H2=0

# %% [markdown]
# ##### **Inputs:** x,y
#
# ##### **Outputs:** v (x,y) (Darcy's velocity); K(x,y) (hydraulic conductivity); h (x,y)(pressure head)

# %%
x = sn.Variable('x',dtype='float64')
y = sn.Variable('y',dtype='float64')
v = sn.Functional('v', [x,y], 2*[20], 'relu')
K = sn.Functional('K', [x,y], 2*[20], 'relu')
h = sn.Functional('h', [x,y], 2*[20], 'relu')

# %% [markdown]
# ##### **Darcy's Equation:**
#
#
# ![image.png](data:image/png;base64,...)

# %%
d1 = sn.Data(v)
d2 = sn.Data(K)
d3 = sn.Data(h)
pde1=pow(diff(h, x),2)
pde2=pow(diff(h, y),2)
C1 = -v-(K*(pow(pde1+pde2,.5)))

# %% [markdown]
# **Boundary Conditions:**
#
# ![image.png](data:image/png;base64,...)

# %%
TOL = 0.001

B1 = (1 - sign(x - (-L1+TOL))) * (h-H1)
B2 = (1 + sign(x - (L1-TOL))) * (h-H2)

B3 = (1 - sign(y - (-L2+TOL))) * (-K*diff(h,y))
B4 = (1 + sign(y - (L2-TOL))) * (-K*diff(h,y))

# %% [markdown]
# Visualising boundary condition functions used:

# %%
psuedo_x=np.linspace(-2,2,100)

psuedo_x_multiplier_B1=(1 - np.sign(psuedo_x - (-L1+TOL))) 
plt.plot(psuedo_x,psuedo_x_multiplier_B1)
plt.title('Multiplier for B1 (h-H1)')
plt.xlabel('x values')
plt.show()

psuedo_x_multiplier_B2=(1 + np.sign(psuedo_x - (L1-TOL))) 
plt.plot(psuedo_x,psuedo_x_multiplier_B2)
plt.title('Multiplier for B2 (h-H2)')
plt.xlabel('x values')
plt.show()

# %%
psuedo_y=np.linspace(-2,2,100)

psuedo_y_multiplier_B3=(1 - np.sign(psuedo_y - (-L2+TOL)))
plt.plot(psuedo_y,psuedo_y_multiplier_B3)
plt.title('Multiplier for B3 (-K*diff(h,y))')
plt.xlabel('y values')
plt.show()

psuedo_y_multiplier_B4=(1 + np.sign(psuedo_y - (L2-TOL))) 
plt.plot(psuedo_y,psuedo_y_multiplier_B4)
plt.title('Multiplier for B4 (-K*diff(h,y))')
plt.xlabel('y values')
plt.show()

# %% [markdown]
# ######  **Model definition**

# %%
m = sn.SciModel([x,y], [d1,d2,d3,C1,B1,B2,B3,B4],loss_func='mse',plot_to_file='./Flow-PINN.png')
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# #### **Dataset**
#
# Datasets in .xlxs format are loaded using pandas python library: https://pandas.pydata.org/

# %%
v_data_df=pd.read_excel('./Darcy_Flux.xlsx')#('/content/gdrive/My Drive/Colab Notebooks/PINN/Darcy_Flux.xlsx')  
h_data_df=pd.read_excel('./Hydraulic_Head.xlsx')#('/content/gdrive/My Drive/Colab Notebooks/PINN/Hydraulic_Head.xlsx')

# %%
x1_data=np.array(v_data_df['X'].values)
x2_data=np.array(v_data_df['Y'].values)

v_data=np.array(v_data_df['VINIT'].values)
print('v_data:',v_data.shape)

K_data=[]
for i in range(len(x1_data)):
  if ((x1_data[i]*x1_data[i])+(x2_data[i]*x2_data[i])<=(.25*L2)):
    K_data.append(0)
  else:
    K_data.append(.5)
K_data=np.array(K_data)
print('K_test:',K_data.shape)

h_data=np.array(h_data_df['FINIT'].values)
print('h_data:',h_data.shape)
# Out:
# v_data: (910,)
# K_test: (910,)
# h_data: (910,)

# %% [markdown]
# **Visualizing data**

# %%
fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_data, x2_data, c=v_data, cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('v (Darcys velocity)')
plt.colorbar()
plt.show()

# %%
fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_data, x2_data, c=K_data, cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('K (Hydraulic Conductivity)')
plt.colorbar()
plt.show()

# %%
fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_data, x2_data, c=h_data, cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('h (Pressure head)')
plt.colorbar()
plt.show()

# %%
train_test_ratio=.7
x1_train, x1_test,x2_train, x2_test, v_train, v_test,K_train, K_test,h_train, h_test = train_test_split(x1_data,x2_data, v_data,K_data,h_data, train_size=train_test_ratio, random_state=512)
print('test:train ratio:',train_test_ratio)
print('Training sizes(x1,x2,v,K,h):',x1_train.shape,x2_train.shape,v_train.shape,K_train.shape,h_train.shape)
print('Testing sizes(x1,x2,v,K,h):',x1_test.shape,x2_test.shape,v_test.shape,K_test.shape,h_test.shape)
C1_train=B1_train=B2_train=B3_train=B4_train = 'zeros'
C1_test=B1_test=B2_test=B3_test=B4_test = np.zeros(x1_test.shape)
# Out:
# test:train ratio: 0.7
# Training sizes(x1,x2,v,K,h): (637,) (637,) (637,) (637,) (637,)
# Testing sizes(x1,x2,v,K,h): (273,) (273,) (273,) (273,) (273,)

# %%
v_pred = v.eval(m, [x1_test,x2_test])
h_pred = h.eval(m, [x1_test,x2_test])
K_pred = K.eval(m, [x1_test,x1_test])
print('MSE for v before training:',(mean_squared_error(v_test,v_pred)))
print('MSE for h before training:',(mean_squared_error(h_test,h_pred)))
print('MSE for K before training:',(mean_squared_error(K_test,K_pred)))
# Out:
# MSE for v before training: 0.2652275173875789
# MSE for h before training: 0.18363165142654894
# MSE for K before training: 0.11417765163425236

# %% [markdown]
# #### **Training**
#
# Details of the model.train function can be found here: https://www.sciann.com/scimodels/#train

# %%
learning_rate=0.001
epochs=50
history = m.train([x1_train,x2_train], [v_train,K_train,h_train,C1_train,B1_train,B2_train,B3_train,B4_train], learning_rate=learning_rate, epochs=epochs, verbose=2,batch_size=100,validation_data=([x1_test,x2_test],[v_test,K_test,h_test,C1_test,B1_test,B2_test,B3_test,B4_test]))
# Out:
# Total samples: 637
# Batch size: 100
# Total batches: 7
#
# Epoch 1/50
# /home/home01/cnlp/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 7/7 - 2s - loss: 0.8696 - v_loss: 0.2311 - K_loss: 0.3796 - h_loss: 0.1620 - sub_loss: 0.0620 - mul_3_loss: 0.0250 - mul_4_loss: 0.0034 - mul_7_loss: 0.0182 - mul_10_loss: 0.0075 - val_loss: 0.6949 - val_v_loss: 0.1797 - val_K_loss: 0.3238 - val_h_loss: 0.1273 - val_sub_loss: 0.0371 - val_mul_3_loss: 0.0177 - val_mul_4_loss: 4.6516e-04 - val_mul_7_loss: 0.0060 - val_mul_10_loss: 0.0028 - lr: 0.0010 - time: 2.3277
# Epoch 2/50
# 7/7 - 2s - loss: 0.5817 - v_loss: 0.1569 - K_loss: 0.2605 - h_loss: 0.1113 - sub_loss: 0.0306 - mul_3_loss: 0.0128 - mul_4_loss: 0.0019 - mul_7_loss: 0.0076 - mul_10_loss: 0.0043 - val_loss: 0.4727 - val_v_loss: 0.1210 - val_K_loss: 0.2219 - val_h_loss: 0.0857 - val_sub_loss: 0.0304 - val_mul_3_loss: 0.0095 - val_mul_4_loss: 2.5557e-04 - val_mul_7_loss: 0.0017 - val_mul_10_loss: 0.0021 - lr: 0.0010 - time: 2.0219
# Epoch 3/50
# 7/7 - 2s - loss: 0.4069 - v_loss: 0.1066 - K_loss: 0.1716 - h_loss: 0.0717 - sub_loss: 0.0384 - mul_3_loss: 0.0080 - mul_4_loss: 0.0013 - mul_7_loss: 0.0039 - mul_10_loss: 0.0023 - val_loss: 0.3561 - val_v_loss: 0.0877 - val_K_loss: 0.1533 - val_h_loss: 0.0534 - val_sub_loss: 0.0529 - val_mul_3_loss: 0.0039 - val_mul_4_loss: 3.6316e-04 - val_mul_7_loss: 0.0028 - val_mul_10_loss: 0.0017 - lr: 0.0010 - time: 2.0119
# Epoch 4/50
# 7/7 - 2s - loss: 0.3174 - v_loss: 0.0802 - K_loss: 0.1275 - h_loss: 0.0446 - sub_loss: 0.0586 - mul_3_loss: 0.0021 - mul_4_loss: 9.7106e-04 - mul_7_loss: 0.0015 - mul_10_loss: 0.0021 - val_loss: 0.2975 - val_v_loss: 0.0682 - val_K_loss: 0.1133 - val_h_loss: 0.0344 - val_sub_loss: 0.0751 - val_mul_3_loss: 9.6562e-04 - val_mul_4_loss: 3.5718e-04 - val_mul_7_loss: 0.0038 - val_mul_10_loss: 0.0014 - lr: 0.0010 - time: 2.1894
# Epoch 5/50
# 7/7 - 2s - loss: 0.2695 - v_loss: 0.0644 - K_loss: 0.0928 - h_loss: 0.0294 - sub_loss: 0.0745 - mul_3_loss: 3.2843e-04 - mul_4_loss: 9.1301e-04 - mul_7_loss: 0.0024 - mul_10_loss: 0.0016 - val_loss: 0.2677 - val_v_loss: 0.0626 - val_K_loss: 0.0879 - val_h_loss: 0.0242 - val_sub_loss: 0.0850 - val_mul_3_loss: 1.4056e-04 - val_mul_4_loss: 3.0137e-04 - val_mul_7_loss: 0.0049 - val_mul_10_loss: 0.0025 - lr: 0.0010 - time: 2.4777
# Epoch 6/50
# 7/7 - 3s - loss: 0.2456 - v_loss: 0.0628 - K_loss: 0.0797 - h_loss: 0.0220 - sub_loss: 0.0775 - mul_3_loss: 1.1239e-04 - mul_4_loss: 0.0010 - mul_7_loss: 0.0022 - mul_10_loss: 0.0016 - val_loss: 0.2434 - val_v_loss: 0.0626 - val_K_loss: 0.0776 - val_h_loss: 0.0205 - val_sub_loss: 0.0765 - val_mul_3_loss: 2.1108e-04 - val_mul_4_loss: 3.5434e-04 - val_mul_7_loss: 0.0039 - val_mul_10_loss: 0.0018 - lr: 0.0010 - time: 2.5476
# Epoch 7/50
# 7/7 - 3s - loss: 0.2282 - v_loss: 0.0634 - K_loss: 0.0715 - h_loss: 0.0200 - sub_loss: 0.0667 - mul_3_loss: 6.1060e-04 - mul_4_loss: 8.3564e-04 - mul_7_loss: 0.0016 - mul_10_loss: 0.0014 - val_loss: 0.2318 - val_v_loss: 0.0693 - val_K_loss: 0.0725 - val_h_loss: 0.0193 - val_sub_loss: 0.0653 - val_mul_3_loss: 3.7914e-04 - val_mul_4_loss: 3.0022e-04 - val_mul_7_loss: 0.0029 - val_mul_10_loss: 0.0019 - lr: 0.0010 - time: 2.7788
# Epoch 8/50
# 7/7 - 3s - loss: 0.2193 - v_loss: 0.0697 - K_loss: 0.0691 - h_loss: 0.0188 - sub_loss: 0.0560 - mul_3_loss: 6.1574e-04 - mul_4_loss: 8.5208e-04 - mul_7_loss: 0.0012 - mul_10_loss: 0.0016 - val_loss: 0.2233 - val_v_loss: 0.0729 - val_K_loss: 0.0698 - val_h_loss: 0.0192 - val_sub_loss: 0.0571 - val_mul_3_loss: 3.4466e-04 - val_mul_4_loss: 2.9836e-04 - val_mul_7_loss: 0.0019 - val_mul_10_loss: 0.0017 - lr: 0.0010 - time: 2.8368
# Epoch 9/50
# 7/7 - 3s - loss: 0.2127 - v_loss: 0.0706 - K_loss: 0.0671 - h_loss: 0.0194 - sub_loss: 0.0516 - mul_3_loss: 4.3628e-04 - mul_4_loss: 9.5276e-04 - mul_7_loss: 9.2685e-04 - mul_10_loss: 0.0020 - val_loss: 0.2171 - val_v_loss: 0.0730 - val_K_loss: 0.0665 - val_h_loss: 0.0196 - val_sub_loss: 0.0544 - val_mul_3_loss: 2.6520e-04 - val_mul_4_loss: 3.9928e-04 - val_mul_7_loss: 0.0014 - val_mul_10_loss: 0.0015 - lr: 0.0010 - time: 3.1130
# Epoch 10/50
# 7/7 - 3s - loss: 0.2072 - v_loss: 0.0704 - K_loss: 0.0647 - h_loss: 0.0194 - sub_loss: 0.0510 - mul_3_loss: 2.9473e-04 - mul_4_loss: 0.0011 - mul_7_loss: 5.4710e-04 - mul_10_loss: 0.0012 - val_loss: 0.2125 - val_v_loss: 0.0702 - val_K_loss: 0.0624 - val_h_loss: 0.0200 - val_sub_loss: 0.0568 - val_mul_3_loss: 1.8870e-04 - val_mul_4_loss: 3.3877e-04 - val_mul_7_loss: 0.0013 - val_mul_10_loss: 0.0014 - lr: 0.0010 - time: 3.2131
# Epoch 11/50
# 7/7 - 4s - loss: 0.2030 - v_loss: 0.0665 - K_loss: 0.0591 - h_loss: 0.0191 - sub_loss: 0.0536 - mul_3_loss: 2.1502e-04 - mul_4_loss: 0.0011 - mul_7_loss: 5.7647e-04 - mul_10_loss: 0.0013 - val_loss: 0.2070 - val_v_loss: 0.0663 - val_K_loss: 0.0591 - val_h_loss: 0.0205 - val_sub_loss: 0.0581 - val_mul_3_loss: 1.3298e-04 - val_mul_4_loss: 4.6143e-04 - val_mul_7_loss: 0.0013 - val_mul_10_loss: 0.0010 - lr: 0.0010 - time: 3.5469
# Epoch 12/50
# 7/7 - 4s - loss: 0.1997 - v_loss: 0.0647 - K_loss: 0.0585 - h_loss: 0.0213 - sub_loss: 0.0542 - mul_3_loss: 1.3082e-04 - mul_4_loss: 0.0016 - mul_7_loss: 5.9789e-04 - mul_10_loss: 9.7477e-04 - val_loss: 0.2048 - val_v_loss: 0.0648 - val_K_loss: 0.0575 - val_h_loss: 0.0207 - val_sub_loss: 0.0590 - val_mul_3_loss: 1.0980e-04 - val_mul_4_loss: 4.0147e-04 - val_mul_7_loss: 0.0013 - val_mul_10_loss: 9.1952e-04 - lr: 0.0010 - time: 3.6594
# Epoch 13/50
# 7/7 - 4s - loss: 0.1974 - v_loss: 0.0622 - K_loss: 0.0561 - h_loss: 0.0191 - sub_loss: 0.0566 - mul_3_loss: 9.2187e-05 - mul_4_loss: 9.1003e-04 - mul_7_loss: 6.6012e-04 - mul_10_loss: 9.8658e-04 - val_loss: 0.2053 - val_v_loss: 0.0658 - val_K_loss: 0.0550 - val_h_loss: 0.0207 - val_sub_loss: 0.0608 - val_mul_3_loss: 1.0378e-04 - val_mul_4_loss: 3.1293e-04 - val_mul_7_loss: 0.0015 - val_mul_10_loss: 0.0010 - lr: 0.0010 - time: 3.7362
# Epoch 14/50
# 7/7 - 4s - loss: 0.1949 - v_loss: 0.0630 - K_loss: 0.0538 - h_loss: 0.0202 - sub_loss: 0.0547 - mul_3_loss: 7.0867e-05 - mul_4_loss: 0.0013 - mul_7_loss: 6.1889e-04 - mul_10_loss: 9.5064e-04 - val_loss: 0.2030 - val_v_loss: 0.0669 - val_K_loss: 0.0545 - val_h_loss: 0.0209 - val_sub_loss: 0.0577 - val_mul_3_loss: 9.4502e-05 - val_mul_4_loss: 4.9708e-04 - val_mul_7_loss: 0.0015 - val_mul_10_loss: 8.5168e-04 - lr: 0.0010 - time: 4.0311
# Epoch 15/50
# 7/7 - 4s - loss: 0.1934 - v_loss: 0.0647 - K_loss: 0.0538 - h_loss: 0.0193 - sub_loss: 0.0541 - mul_3_loss: 5.6330e-05 - mul_4_loss: 9.6568e-04 - mul_7_loss: 6.6511e-04 - mul_10_loss: 0.0010 - val_loss: 0.2010 - val_v_loss: 0.0679 - val_K_loss: 0.0534 - val_h_loss: 0.0207 - val_sub_loss: 0.0563 - val_mul_3_loss: 9.5423e-05 - val_mul_4_loss: 3.4477e-04 - val_mul_7_loss: 0.0014 - val_mul_10_loss: 7.8893e-04 - lr: 0.0010 - time: 4.2240
# Epoch 16/50
# 7/7 - 4s - loss: 0.1913 - v_loss: 0.0653 - K_loss: 0.0522 - h_loss: 0.0199 - sub_loss: 0.0522 - mul_3_loss: 6.6536e-05 - mul_4_loss: 0.0011 - mul_7_loss: 6.3740e-04 - mul_10_loss: 0.0010 - val_loss: 0.1989 - val_v_loss: 0.0679 - val_K_loss: 0.0519 - val_h_loss: 0.0208 - val_sub_loss: 0.0557 - val_mul_3_loss: 9.9642e-05 - val_mul_4_loss: 4.6790e-04 - val_mul_7_loss: 0.0014 - val_mul_10_loss: 7.6582e-04 - lr: 0.0010 - time: 4.3989
# Epoch 17/50
# 7/7 - 5s - loss: 0.1903 - v_loss: 0.0656 - K_loss: 0.0503 - h_loss: 0.0197 - sub_loss: 0.0522 - mul_3_loss: 5.3164e-05 - mul_4_loss: 0.0013 - mul_7_loss: 5.9135e-04 - mul_10_loss: 8.8439e-04 - val_loss: 0.1985 - val_v_loss: 0.0675 - val_K_loss: 0.0512 - val_h_loss: 0.0207 - val_sub_loss: 0.0559 - val_mul_3_loss: 1.0981e-04 - val_mul_4_loss: 4.0146e-04 - val_mul_7_loss: 0.0016 - val_mul_10_loss: 0.0011 - lr: 0.0010 - time: 4.6513
# Epoch 18/50
# 7/7 - 5s - loss: 0.1886 - v_loss: 0.0655 - K_loss: 0.0498 - h_loss: 0.0189 - sub_loss: 0.0521 - mul_3_loss: 4.3121e-05 - mul_4_loss: 9.5882e-04 - mul_7_loss: 5.9293e-04 - mul_10_loss: 8.8573e-04 - val_loss: 0.1980 - val_v_loss: 0.0668 - val_K_loss: 0.0505 - val_h_loss: 0.0207 - val_sub_loss: 0.0567 - val_mul_3_loss: 1.2439e-04 - val_mul_4_loss: 3.5150e-04 - val_mul_7_loss: 0.0016 - val_mul_10_loss: 0.0012 - lr: 0.0010 - time: 4.8406
# Epoch 19/50
# 7/7 - 5s - loss: 0.1879 - v_loss: 0.0642 - K_loss: 0.0480 - h_loss: 0.0191 - sub_loss: 0.0530 - mul_3_loss: 4.2379e-05 - mul_4_loss: 9.8606e-04 - mul_7_loss: 5.7556e-04 - mul_10_loss: 7.7033e-04 - val_loss: 0.1944 - val_v_loss: 0.0656 - val_K_loss: 0.0490 - val_h_loss: 0.0211 - val_sub_loss: 0.0557 - val_mul_3_loss: 1.3889e-04 - val_mul_4_loss: 5.5803e-04 - val_mul_7_loss: 0.0013 - val_mul_10_loss: 9.4660e-04 - lr: 0.0010 - time: 5.0387
# Epoch 20/50
# 7/7 - 5s - loss: 0.1870 - v_loss: 0.0629 - K_loss: 0.0466 - h_loss: 0.0196 - sub_loss: 0.0544 - mul_3_loss: 7.0561e-05 - mul_4_loss: 0.0016 - mul_7_loss: 5.9941e-04 - mul_10_loss: 6.7209e-04 - val_loss: 0.1951 - val_v_loss: 0.0665 - val_K_loss: 0.0481 - val_h_loss: 0.0210 - val_sub_loss: 0.0566 - val_mul_3_loss: 1.6305e-04 - val_mul_4_loss: 4.5570e-04 - val_mul_7_loss: 0.0014 - val_mul_10_loss: 8.9672e-04 - lr: 0.0010 - time: 5.1773
# Epoch 21/50
# 7/7 - 5s - loss: 0.1862 - v_loss: 0.0629 - K_loss: 0.0465 - h_loss: 0.0198 - sub_loss: 0.0540 - mul_3_loss: 5.8506e-05 - mul_4_loss: 0.0010 - mul_7_loss: 6.5849e-04 - mul_10_loss: 6.5883e-04 - val_loss: 0.1939 - val_v_loss: 0.0669 - val_K_loss: 0.0460 - val_h_loss: 0.0213 - val_sub_loss: 0.0567 - val_mul_3_loss: 2.1256e-04 - val_mul_4_loss: 4.5215e-04 - val_mul_7_loss: 0.0014 - val_mul_10_loss: 8.8726e-04 - lr: 0.0010 - time: 5.3991
# Epoch 22/50
# 7/7 - 6s - loss: 0.1849 - v_loss: 0.0632 - K_loss: 0.0442 - h_loss: 0.0197 - sub_loss: 0.0540 - mul_3_loss: 6.2090e-05 - mul_4_loss: 0.0010 - mul_7_loss: 5.9102e-04 - mul_10_loss: 6.0070e-04 - val_loss: 0.1923 - val_v_loss: 0.0674 - val_K_loss: 0.0454 - val_h_loss: 0.0211 - val_sub_loss: 0.0555 - val_mul_3_loss: 2.2749e-04 - val_mul_4_loss: 3.9422e-04 - val_mul_7_loss: 0.0014 - val_mul_10_loss: 9.1825e-04 - lr: 0.0010 - time: 5.6270
# Epoch 23/50
# 7/7 - 6s - loss: 0.1832 - v_loss: 0.0643 - K_loss: 0.0448 - h_loss: 0.0207 - sub_loss: 0.0518 - mul_3_loss: 6.4563e-05 - mul_4_loss: 0.0016 - mul_7_loss: 6.9839e-04 - mul_10_loss: 7.7035e-04 - val_loss: 0.1904 - val_v_loss: 0.0672 - val_K_loss: 0.0442 - val_h_loss: 0.0210 - val_sub_loss: 0.0550 - val_mul_3_loss: 2.4140e-04 - val_mul_4_loss: 4.2274e-04 - val_mul_7_loss: 0.0013 - val_mul_10_loss: 9.1839e-04 - lr: 0.0010 - time: 5.7471
# Epoch 24/50
# 7/7 - 6s - loss: 0.1820 - v_loss: 0.0648 - K_loss: 0.0451 - h_loss: 0.0188 - sub_loss: 0.0534 - mul_3_loss: 7.5205e-05 - mul_4_loss: 9.0120e-04 - mul_7_loss: 9.9594e-04 - mul_10_loss: 8.2195e-04 - val_loss: 0.1884 - val_v_loss: 0.0665 - val_K_loss: 0.0436 - val_h_loss: 0.0209 - val_sub_loss: 0.0547 - val_mul_3_loss: 2.4108e-04 - val_mul_4_loss: 4.5066e-04 - val_mul_7_loss: 0.0011 - val_mul_10_loss: 8.6102e-04 - lr: 0.0010 - time: 5.9553
# Epoch 25/50
# 7/7 - 6s - loss: 0.1800 - v_loss: 0.0636 - K_loss: 0.0429 - h_loss: 0.0198 - sub_loss: 0.0525 - mul_3_loss: 7.8879e-05 - mul_4_loss: 0.0012 - mul_7_loss: 6.2741e-04 - mul_10_loss: 6.9104e-04 - val_loss: 0.1866 - val_v_loss: 0.0662 - val_K_loss: 0.0415 - val_h_loss: 0.0211 - val_sub_loss: 0.0551 - val_mul_3_loss: 2.6174e-04 - val_mul_4_loss: 5.5050e-04 - val_mul_7_loss: 0.0011 - val_mul_10_loss: 8.8547e-04 - lr: 0.0010 - time: 6.1644
# Epoch 26/50
# 7/7 - 7s - loss: 0.1785 - v_loss: 0.0624 - K_loss: 0.0397 - h_loss: 0.0206 - sub_loss: 0.0522 - mul_3_loss: 1.2357e-04 - mul_4_loss: 0.0012 - mul_7_loss: 3.5931e-04 - mul_10_loss: 8.3012e-04 - val_loss: 0.1867 - val_v_loss: 0.0656 - val_K_loss: 0.0404 - val_h_loss: 0.0210 - val_sub_loss: 0.0570 - val_mul_3_loss: 2.8755e-04 - val_mul_4_loss: 4.0298e-04 - val_mul_7_loss: 0.0012 - val_mul_10_loss: 8.2083e-04 - lr: 0.0010 - time: 6.6434
# Epoch 27/50
# 7/7 - 7s - loss: 0.1771 - v_loss: 0.0625 - K_loss: 0.0407 - h_loss: 0.0204 - sub_loss: 0.0521 - mul_3_loss: 1.8353e-04 - mul_4_loss: 0.0010 - mul_7_loss: 4.4345e-04 - mul_10_loss: 6.4610e-04 - val_loss: 0.1835 - val_v_loss: 0.0647 - val_K_loss: 0.0397 - val_h_loss: 0.0217 - val_sub_loss: 0.0547 - val_mul_3_loss: 3.2387e-04 - val_mul_4_loss: 5.6725e-04 - val_mul_7_loss: 0.0010 - val_mul_10_loss: 7.6639e-04 - lr: 0.0010 - time: 6.5203
# Epoch 28/50
# 7/7 - 7s - loss: 0.1763 - v_loss: 0.0606 - K_loss: 0.0370 - h_loss: 0.0203 - sub_loss: 0.0510 - mul_3_loss: 2.2192e-04 - mul_4_loss: 0.0025 - mul_7_loss: 4.2488e-04 - mul_10_loss: 7.0331e-04 - val_loss: 0.1854 - val_v_loss: 0.0648 - val_K_loss: 0.0383 - val_h_loss: 0.0216 - val_sub_loss: 0.0584 - val_mul_3_loss: 4.0144e-04 - val_mul_4_loss: 1.8503e-04 - val_mul_7_loss: 9.8633e-04 - val_mul_10_loss: 7.6214e-04 - lr: 0.0010 - time: 6.6754
# Epoch 29/50
# 7/7 - 7s - loss: 0.1760 - v_loss: 0.0605 - K_loss: 0.0378 - h_loss: 0.0213 - sub_loss: 0.0530 - mul_3_loss: 2.7440e-04 - mul_4_loss: 8.4215e-04 - mul_7_loss: 5.0724e-04 - mul_10_loss: 6.5764e-04 - val_loss: 0.1821 - val_v_loss: 0.0653 - val_K_loss: 0.0391 - val_h_loss: 0.0220 - val_sub_loss: 0.0533 - val_mul_3_loss: 4.0136e-04 - val_mul_4_loss: 5.5272e-04 - val_mul_7_loss: 7.2399e-04 - val_mul_10_loss: 6.5382e-04 - lr: 0.0010 - time: 6.9633
# Epoch 30/50
# 7/7 - 7s - loss: 0.1743 - v_loss: 0.0615 - K_loss: 0.0381 - h_loss: 0.0218 - sub_loss: 0.0495 - mul_3_loss: 2.8266e-04 - mul_4_loss: 0.0017 - mul_7_loss: 4.2847e-04 - mul_10_loss: 6.2055e-04 - val_loss: 0.1825 - val_v_loss: 0.0656 - val_K_loss: 0.0380 - val_h_loss: 0.0220 - val_sub_loss: 0.0546 - val_mul_3_loss: 4.6455e-04 - val_mul_4_loss: 3.8645e-04 - val_mul_7_loss: 8.9122e-04 - val_mul_10_loss: 6.4941e-04 - lr: 0.0010 - time: 7.2818
# Epoch 31/50
# 7/7 - 7s - loss: 0.1735 - v_loss: 0.0628 - K_loss: 0.0366 - h_loss: 0.0211 - sub_loss: 0.0513 - mul_3_loss: 3.2180e-04 - mul_4_loss: 0.0010 - mul_7_loss: 4.3539e-04 - mul_10_loss: 8.2299e-04 - val_loss: 0.1810 - val_v_loss: 0.0648 - val_K_loss: 0.0362 - val_h_loss: 0.0224 - val_sub_loss: 0.0551 - val_mul_3_loss: 5.0502e-04 - val_mul_4_loss: 5.4364e-04 - val_mul_7_loss: 8.4740e-04 - val_mul_10_loss: 6.5288e-04 - lr: 0.0010 - time: 7.3285
# Epoch 32/50
# 7/7 - 7s - loss: 0.1721 - v_loss: 0.0629 - K_loss: 0.0361 - h_loss: 0.0201 - sub_loss: 0.0511 - mul_3_loss: 3.4831e-04 - mul_4_loss: 0.0017 - mul_7_loss: 3.4600e-04 - mul_10_loss: 8.8064e-04 - val_loss: 0.1808 - val_v_loss: 0.0634 - val_K_loss: 0.0367 - val_h_loss: 0.0228 - val_sub_loss: 0.0554 - val_mul_3_loss: 5.6857e-04 - val_mul_4_loss: 4.1925e-04 - val_mul_7_loss: 6.5554e-04 - val_mul_10_loss: 7.9378e-04 - lr: 0.0010 - time: 7.4979
# Epoch 33/50
# 7/7 - 8s - loss: 0.1719 - v_loss: 0.0602 - K_loss: 0.0351 - h_loss: 0.0203 - sub_loss: 0.0514 - mul_3_loss: 4.0685e-04 - mul_4_loss: 0.0012 - mul_7_loss: 3.1747e-04 - mul_10_loss: 6.1626e-04 - val_loss: 0.1817 - val_v_loss: 0.0632 - val_K_loss: 0.0374 - val_h_loss: 0.0227 - val_sub_loss: 0.0559 - val_mul_3_loss: 6.0374e-04 - val_mul_4_loss: 3.9518e-04 - val_mul_7_loss: 4.6594e-04 - val_mul_10_loss: 0.0011 - lr: 0.0010 - time: 7.7061
# Epoch 34/50
# 7/7 - 8s - loss: 0.1716 - v_loss: 0.0598 - K_loss: 0.0363 - h_loss: 0.0211 - sub_loss: 0.0514 - mul_3_loss: 4.1617e-04 - mul_4_loss: 0.0013 - mul_7_loss: 3.4732e-04 - mul_10_loss: 0.0013 - val_loss: 0.1802 - val_v_loss: 0.0631 - val_K_loss: 0.0371 - val_h_loss: 0.0231 - val_sub_loss: 0.0544 - val_mul_3_loss: 6.5635e-04 - val_mul_4_loss: 4.5308e-04 - val_mul_7_loss: 3.9391e-04 - val_mul_10_loss: 0.0010 - lr: 0.0010 - time: 7.8508
# Epoch 35/50
# 7/7 - 8s - loss: 0.1717 - v_loss: 0.0602 - K_loss: 0.0355 - h_loss: 0.0207 - sub_loss: 0.0525 - mul_3_loss: 5.4265e-04 - mul_4_loss: 8.7027e-04 - mul_7_loss: 2.9886e-04 - mul_10_loss: 0.0012 - val_loss: 0.1810 - val_v_loss: 0.0633 - val_K_loss: 0.0364 - val_h_loss: 0.0235 - val_sub_loss: 0.0551 - val_mul_3_loss: 7.5062e-04 - val_mul_4_loss: 3.4810e-04 - val_mul_7_loss: 4.4524e-04 - val_mul_10_loss: 0.0012 - lr: 0.0010 - time: 8.2744
# Epoch 36/50
# 7/7 - 8s - loss: 0.1703 - v_loss: 0.0610 - K_loss: 0.0357 - h_loss: 0.0217 - sub_loss: 0.0511 - mul_3_loss: 7.4081e-04 - mul_4_loss: 9.5916e-04 - mul_7_loss: 4.1154e-04 - mul_10_loss: 0.0010 - val_loss: 0.1810 - val_v_loss: 0.0634 - val_K_loss: 0.0367 - val_h_loss: 0.0242 - val_sub_loss: 0.0533 - val_mul_3_loss: 8.3784e-04 - val_mul_4_loss: 5.6337e-04 - val_mul_7_loss: 4.1547e-04 - val_mul_10_loss: 0.0016 - lr: 0.0010 - time: 8.2832
# Epoch 37/50
# 7/7 - 8s - loss: 0.1707 - v_loss: 0.0601 - K_loss: 0.0365 - h_loss: 0.0226 - sub_loss: 0.0509 - mul_3_loss: 7.6578e-04 - mul_4_loss: 9.8465e-04 - mul_7_loss: 2.1570e-04 - mul_10_loss: 0.0015 - val_loss: 0.1807 - val_v_loss: 0.0630 - val_K_loss: 0.0373 - val_h_loss: 0.0240 - val_sub_loss: 0.0537 - val_mul_3_loss: 8.8662e-04 - val_mul_4_loss: 2.9655e-04 - val_mul_7_loss: 3.7936e-04 - val_mul_10_loss: 0.0011 - lr: 0.0010 - time: 8.4451
# Epoch 38/50
# 7/7 - 9s - loss: 0.1704 - v_loss: 0.0610 - K_loss: 0.0352 - h_loss: 0.0205 - sub_loss: 0.0513 - mul_3_loss: 7.2802e-04 - mul_4_loss: 7.6796e-04 - mul_7_loss: 2.2588e-04 - mul_10_loss: 0.0013 - val_loss: 0.1797 - val_v_loss: 0.0619 - val_K_loss: 0.0364 - val_h_loss: 0.0244 - val_sub_loss: 0.0543 - val_mul_3_loss: 8.6866e-04 - val_mul_4_loss: 5.0363e-04 - val_mul_7_loss: 3.1410e-04 - val_mul_10_loss: 0.0011 - lr: 0.0010 - time: 8.6534
# Epoch 39/50
# 7/7 - 9s - loss: 0.1705 - v_loss: 0.0604 - K_loss: 0.0355 - h_loss: 0.0201 - sub_loss: 0.0539 - mul_3_loss: 6.7033e-04 - mul_4_loss: 0.0013 - mul_7_loss: 1.7704e-04 - mul_10_loss: 0.0015 - val_loss: 0.1831 - val_v_loss: 0.0622 - val_K_loss: 0.0353 - val_h_loss: 0.0245 - val_sub_loss: 0.0582 - val_mul_3_loss: 0.0011 - val_mul_4_loss: 3.1084e-04 - val_mul_7_loss: 3.6967e-04 - val_mul_10_loss: 0.0012 - lr: 0.0010 - time: 9.0197
# Epoch 40/50
# 7/7 - 9s - loss: 0.1707 - v_loss: 0.0588 - K_loss: 0.0331 - h_loss: 0.0212 - sub_loss: 0.0526 - mul_3_loss: 8.1870e-04 - mul_4_loss: 0.0010 - mul_7_loss: 1.6584e-04 - mul_10_loss: 0.0013 - val_loss: 0.1822 - val_v_loss: 0.0628 - val_K_loss: 0.0358 - val_h_loss: 0.0253 - val_sub_loss: 0.0545 - val_mul_3_loss: 0.0013 - val_mul_4_loss: 5.3146e-04 - val_mul_7_loss: 0.0010 - val_mul_10_loss: 9.0796e-04 - lr: 0.0010 - time: 9.0255
# Epoch 41/50
# 7/7 - 9s - loss: 0.1705 - v_loss: 0.0605 - K_loss: 0.0331 - h_loss: 0.0213 - sub_loss: 0.0504 - mul_3_loss: 0.0014 - mul_4_loss: 0.0014 - mul_7_loss: 4.7527e-04 - mul_10_loss: 8.0574e-04 - val_loss: 0.1810 - val_v_loss: 0.0628 - val_K_loss: 0.0349 - val_h_loss: 0.0250 - val_sub_loss: 0.0547 - val_mul_3_loss: 0.0013 - val_mul_4_loss: 3.4125e-04 - val_mul_7_loss: 0.0011 - val_mul_10_loss: 8.5197e-04 - lr: 0.0010 - time: 9.2524
# Epoch 42/50
# 7/7 - 9s - loss: 0.1699 - v_loss: 0.0601 - K_loss: 0.0314 - h_loss: 0.0206 - sub_loss: 0.0521 - mul_3_loss: 0.0011 - mul_4_loss: 0.0012 - mul_7_loss: 0.0013 - mul_10_loss: 6.9060e-04 - val_loss: 0.1790 - val_v_loss: 0.0623 - val_K_loss: 0.0339 - val_h_loss: 0.0250 - val_sub_loss: 0.0544 - val_mul_3_loss: 0.0010 - val_mul_4_loss: 5.3468e-04 - val_mul_7_loss: 9.9315e-04 - val_mul_10_loss: 8.4021e-04 - lr: 0.0010 - time: 9.4598
# Epoch 43/50
# 7/7 - 10s - loss: 0.1681 - v_loss: 0.0595 - K_loss: 0.0316 - h_loss: 0.0233 - sub_loss: 0.0504 - mul_3_loss: 7.7259e-04 - mul_4_loss: 0.0014 - mul_7_loss: 5.5308e-04 - mul_10_loss: 6.9151e-04 - val_loss: 0.1776 - val_v_loss: 0.0615 - val_K_loss: 0.0334 - val_h_loss: 0.0247 - val_sub_loss: 0.0545 - val_mul_3_loss: 0.0013 - val_mul_4_loss: 2.6401e-04 - val_mul_7_loss: 0.0014 - val_mul_10_loss: 6.3456e-04 - lr: 0.0010 - time: 9.8388
# Epoch 44/50
# 7/7 - 10s - loss: 0.1673 - v_loss: 0.0601 - K_loss: 0.0311 - h_loss: 0.0215 - sub_loss: 0.0498 - mul_3_loss: 0.0012 - mul_4_loss: 0.0010 - mul_7_loss: 8.5181e-04 - mul_10_loss: 7.8841e-04 - val_loss: 0.1760 - val_v_loss: 0.0620 - val_K_loss: 0.0336 - val_h_loss: 0.0249 - val_sub_loss: 0.0517 - val_mul_3_loss: 0.0015 - val_mul_4_loss: 3.9908e-04 - val_mul_7_loss: 0.0010 - val_mul_10_loss: 8.9757e-04 - lr: 0.0010 - time: 9.8052
# Epoch 45/50
# 7/7 - 10s - loss: 0.1659 - v_loss: 0.0598 - K_loss: 0.0321 - h_loss: 0.0218 - sub_loss: 0.0504 - mul_3_loss: 0.0011 - mul_4_loss: 0.0010 - mul_7_loss: 7.3271e-04 - mul_10_loss: 8.7556e-04 - val_loss: 0.1753 - val_v_loss: 0.0614 - val_K_loss: 0.0329 - val_h_loss: 0.0249 - val_sub_loss: 0.0524 - val_mul_3_loss: 0.0014 - val_mul_4_loss: 4.4398e-04 - val_mul_7_loss: 9.7344e-04 - val_mul_10_loss: 9.2052e-04 - lr: 0.0010 - time: 9.9681
# Epoch 46/50
# 7/7 - 10s - loss: 0.1664 - v_loss: 0.0582 - K_loss: 0.0299 - h_loss: 0.0226 - sub_loss: 0.0502 - mul_3_loss: 0.0011 - mul_4_loss: 0.0011 - mul_7_loss: 5.0763e-04 - mul_10_loss: 7.1517e-04 - val_loss: 0.1774 - val_v_loss: 0.0607 - val_K_loss: 0.0323 - val_h_loss: 0.0251 - val_sub_loss: 0.0558 - val_mul_3_loss: 0.0013 - val_mul_4_loss: 2.6062e-04 - val_mul_7_loss: 9.9279e-04 - val_mul_10_loss: 9.8835e-04 - lr: 0.0010 - time: 10.3807
# Epoch 47/50
# 7/7 - 10s - loss: 0.1658 - v_loss: 0.0575 - K_loss: 0.0311 - h_loss: 0.0222 - sub_loss: 0.0499 - mul_3_loss: 0.0010 - mul_4_loss: 0.0014 - mul_7_loss: 6.1183e-04 - mul_10_loss: 8.0740e-04 - val_loss: 0.1772 - val_v_loss: 0.0610 - val_K_loss: 0.0318 - val_h_loss: 0.0253 - val_sub_loss: 0.0556 - val_mul_3_loss: 0.0014 - val_mul_4_loss: 1.9405e-04 - val_mul_7_loss: 8.4386e-04 - val_mul_10_loss: 0.0011 - lr: 0.0010 - time: 10.4073
# Epoch 48/50
# 7/7 - 11s - loss: 0.1667 - v_loss: 0.0597 - K_loss: 0.0308 - h_loss: 0.0238 - sub_loss: 0.0523 - mul_3_loss: 0.0012 - mul_4_loss: 4.8482e-04 - mul_7_loss: 5.8900e-04 - mul_10_loss: 8.6962e-04 - val_loss: 0.1769 - val_v_loss: 0.0613 - val_K_loss: 0.0323 - val_h_loss: 0.0261 - val_sub_loss: 0.0535 - val_mul_3_loss: 0.0017 - val_mul_4_loss: 3.3845e-04 - val_mul_7_loss: 7.8700e-04 - val_mul_10_loss: 8.0983e-04 - lr: 0.0010 - time: 10.5674
# Epoch 49/50
# 7/7 - 11s - loss: 0.1659 - v_loss: 0.0593 - K_loss: 0.0305 - h_loss: 0.0248 - sub_loss: 0.0477 - mul_3_loss: 0.0016 - mul_4_loss: 0.0014 - mul_7_loss: 4.9078e-04 - mul_10_loss: 8.3683e-04 - val_loss: 0.1746 - val_v_loss: 0.0614 - val_K_loss: 0.0314 - val_h_loss: 0.0276 - val_sub_loss: 0.0498 - val_mul_3_loss: 0.0022 - val_mul_4_loss: 6.3320e-04 - val_mul_7_loss: 9.2646e-04 - val_mul_10_loss: 5.8363e-04 - lr: 0.0010 - time: 10.9660
# Epoch 50/50
# 7/7 - 11s - loss: 0.1656 - v_loss: 0.0574 - K_loss: 0.0282 - h_loss: 0.0237 - sub_loss: 0.0495 - mul_3_loss: 0.0020 - mul_4_loss: 0.0017 - mul_7_loss: 5.2095e-04 - mul_10_loss: 5.0885e-04 - val_loss: 0.1751 - val_v_loss: 0.0603 - val_K_loss: 0.0297 - val_h_loss: 0.0263 - val_sub_loss: 0.0546 - val_mul_3_loss: 0.0024 - val_mul_4_loss: 1.7893e-04 - val_mul_7_loss: 9.3416e-04 - val_mul_10_loss: 6.6172e-04 - lr: 0.0010 - time: 10.9609

# %% [markdown]
# #### **Plotting Loss**

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'v_loss', 'K_loss', 'h_loss', 'sub_loss', 'mul_3_loss', 'mul_4_loss', 'mul_7_loss', 'mul_10_loss', 'val_loss', 'val_v_loss', 'val_K_loss', 'val_h_loss', 'val_sub_loss', 'val_mul_3_loss', 'val_mul_4_loss', 'val_mul_7_loss', 'val_mul_10_loss', 'lr', 'time'])

# %%
plt.plot(range(0,epochs),history.history['v_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_v_loss'],label='test')
plt.title('v_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['K_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_K_loss'],label='test')
plt.title('K_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['h_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_h_loss'],label='test')
plt.title('h_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['mul_13_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_mul_13_loss'],label='test')
plt.title('B1_loss vs epoch')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-66f2c08b88c6> in <module>()
# ----> 1 plt.plot(range(0,epochs),history.history['mul_13_loss'],color='red',label='train')
#       2 plt.plot(range(0,epochs),history.history['val_mul_13_loss'],label='test')
#       3 plt.title('B1_loss vs epoch')
#       4 plt.legend()
#       5 plt.show()
#
# KeyError: 'mul_13_loss'

# %%
plt.plot(range(0,epochs),history.history['mul_14_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_mul_14_loss'],label='test')
plt.title('B2_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['mul_17_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_mul_17_loss'],label='test')
plt.title('B3_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['mul_20_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_mul_20_loss'],label='test')
plt.title('B4_loss vs epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(0,epochs),history.history['sub_8_loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_sub_8_loss'],label='test')
plt.legend()
plt.title('PDE loss vs epoch')
plt.show()

# %%
plt.plot(range(0,epochs),history.history['loss'],color='red',label='train')
plt.plot(range(0,epochs),history.history['val_loss'],label='test')
plt.title('Net loss vs epoch')
plt.legend()
plt.show()

# %% [markdown]
# #### **Testing**

# %%
v_pred = v.eval(m, [x1_test,x2_test])
h_pred = h.eval(m, [x1_test,x2_test])
K_pred = K.eval(m, [x1_test,x2_test])
print('MSE for v after training:',round(mean_squared_error(v_test,v_pred),10))
print('MSE for h after training:',round(mean_squared_error(h_test,h_pred),10))
print('MSE for K after training:',round(mean_squared_error(K_test,K_pred),10))

# %%
fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_test, x2_test, c= v.eval(m, [x1_test,x2_test]), cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('v_pred (Darcy velocity)')
plt.colorbar()
plt.show()

fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_test, x2_test, c= v_test, cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('v_test (Darcy velocity)')
plt.colorbar()
plt.show()

# %%
fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_test, x2_test, c= K.eval(m, [x1_test,x2_test]), cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('K_pred (Hydraulic Conductivity)')
plt.colorbar()
plt.show()

fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_test, x2_test, c= K_test, cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('K_test (Hydraulic Conductivity)')
plt.colorbar()
plt.show()

# %%
fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_test, x2_test, c= h.eval(m, [x1_test,x2_test]), cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('h_pred (Pressure head)')
plt.colorbar()
plt.show()

fig = plt.figure(figsize=(6, 3))
plt.scatter(x1_test, x2_test, c= h_test, cmap='viridis',linewidths=.0001)
plt.xlabel('-1=<x<=1')
plt.ylabel('-.5=<y<=.5')
plt.title('h_test (Pressure head)')
plt.colorbar()
plt.show()

# %% [markdown]
# #### **Simulating**

# %%
x1_sim, x2_sim = np.meshgrid(np.linspace(-1, 1, 100), np.linspace(-.5, .5, 100))
fig = plt.figure(figsize=(6, 3))
v_pred_sim =np.array(v.eval(m, [x1_sim,x2_sim]))
plt.contourf(x1_sim, x2_sim, v_pred_sim)
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.title('Darcys Veloctiy')
plt.show()

# %%
x1_sim, x2_sim = np.meshgrid(np.linspace(-1, 1, 100), np.linspace(-.5, .5, 100))
fig = plt.figure(figsize=(6, 3))
v_pred_sim =np.array(K.eval(m, [x1_sim,x2_sim]))
plt.contourf(x1_sim, x2_sim, v_pred_sim)
plt.xlabel('X')
plt.ylabel('Y')
plt.colorbar()
plt.title('Hydraulic Conductivty')
plt.show()

# %%
x1_sim, x2_sim = np.meshgrid(np.linspace(-1, 1, 100), np.linspace(-.5, .5, 100))
fig = plt.figure(figsize=(6, 3))
v_pred_sim =np.array(h.eval(m, [x1_sim,x2_sim]))
plt.contourf(x1_sim, x2_sim, v_pred_sim)
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.title('Pressure head')
plt.show()

# %%
print(x1_sim.shape,x2_sim.shape,v_pred_sim.shape)
